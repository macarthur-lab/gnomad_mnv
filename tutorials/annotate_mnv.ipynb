# %% [markdown]
# # 2. annotate MNV using VEP
#
# In this section we will walk through how to annotate MNV using vep in hail.
#
# In order to reproduce this tutorial results, you will need to set up your vep configuration.
# See [Hail docs](https://hail.is/docs/0.2/methods/genetics.html?highlight=vep#hail.methods.vep) for vep configuration set up.
#
# Similar to the last tutorial, we ran
#
# `cluster start mycluster --num-preemptible-workers 8 --vep --init gs://gnomad-public/tools/inits/master-init.sh`
# Followed by
# `cluster connect mycluster notebook`
#
# To build the jupyter notebook in google cloud cluster.

# %%
#importing hail, and specifying the vep config
import hail as hl
import hail.expr.aggregators as agg
from typing import *
vep_config = "gs://gnomad-resources/loftee-beta/vep85-loftee-gcloud.json"  # this is the config that actually works!

# %%
#import the mnv table created in the tutorial step 1.
mnv = hl.read_table("gs://gnomad-qingbowang/MNV/demo_et_combined.ht")
mnv.show()
# Out:
# Initializing Spark and Hail with default parameters...
# Running on Apache Spark version 2.2.3
# SparkUI available at http://10.128.0.44:4043
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.11-61a2083d5773
# LOGGING: writing to /home/hail/hail-20190310-0052-0.2.11-61a2083d5773.log
# +---------------+------------+---------------+--------------+-------+----------+-------+
# | locus         | alleles    | prev_locus    | prev_alleles |  dist |       AF |    AC |
# +---------------+------------+---------------+--------------+-------+----------+-------+
# | locus<GRCh37> | array<str> | locus<GRCh37> | array<str>   | int32 |  float64 | int32 |
# +---------------+------------+---------------+--------------+-------+----------+-------+
# | 1:10506       | ["C","G"]  | 1:10505       | ["A","T"]    |     1 | 2.00e-04 |     1 |
# | 1:13118       | ["A","G"]  | 1:13116       | ["T","G"]    |     2 | 9.70e-02 |   486 |
# | 1:48328       | ["A","T"]  | 1:48327       | ["C","A"]    |     1 | 4.39e-03 |    22 |
# | 1:49989       | ["A","G"]  | 1:49988       | ["T","A"]    |     1 | 5.79e-03 |    29 |
# | 1:51049       | ["A","C"]  | 1:51047       | ["A","T"]    |     2 | 1.60e-03 |     8 |
# | 1:51050       | ["A","T"]  | 1:51049       | ["A","C"]    |     1 | 1.60e-03 |     8 |
# | 1:55165       | ["A","G"]  | 1:55164       | ["C","A"]    |     1 | 2.00e-04 |     1 |
# | 1:55545       | ["C","T"]  | 1:55544       | ["T","G"]    |     1 | 2.39e-01 |  1198 |
# | 1:57264       | ["T","G"]  | 1:57262       | ["T","G"]    |     2 | 1.40e-03 |     7 |
# | 1:74792       | ["G","A"]  | 1:74790       | ["C","G"]    |     2 | 3.77e-02 |   189 |
# +---------------+------------+---------------+--------------+-------+----------+-------+
#
# +----------+----------+---------+--------------+----------+----------+----------+
# | filters  |  prev_AF | prev_AC | prev_filters | n_hethet | n_hethom | n_homhom |
# +----------+----------+---------+--------------+----------+----------+----------+
# | set<str> |  float64 |   int32 | set<str>     |    int64 |    int64 |    int64 |
# +----------+----------+---------+--------------+----------+----------+----------+
# | {}       | 2.00e-04 |       1 | {}           |        1 |        0 |        0 |
# | {}       | 9.70e-02 |     486 | {}           |      414 |       36 |        0 |
# | {}       | 4.39e-03 |      22 | {}           |       22 |        0 |        0 |
# | {}       | 5.79e-03 |      29 | {}           |       29 |        0 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# | {}       | 9.23e-01 |    4624 | {}           |        0 |        0 |        1 |
# | {}       | 2.00e-04 |       1 | {}           |        1 |        0 |        0 |
# | {}       | 1.40e-03 |       7 | {}           |        7 |        0 |        0 |
# | {}       | 3.77e-02 |     189 | {}           |      187 |        1 |        0 |
# +----------+----------+---------+--------------+----------+----------+----------+
#
# +---------+
# | n_total |
# +---------+
# |   int64 |
# +---------+
# |       1 |
# |     450 |
# |      22 |
# |      29 |
# |       8 |
# |       8 |
# |       1 |
# |       1 |
# |       7 |
# |     188 |
# +---------+
# showing top 10 rows

# %% [markdown]
# ## annotating the SNP effects
#
# This is relatively straightforward. Let the SNP of `prev_locus` be SNP1, and the other one be SNP2 (i.e. SNP2 is downstream).
#
# Since the vep function in hail takes `locus` and `alleles`, it is easier if we first annotate the SNP2 consequence by vep:

# %%
mnv = mnv.key_by("locus","alleles")
mnv = hl.vep(mnv, vep_config, name="snp2_vep")

# %% [markdown]
# Next we want to annotate the SNP1 consequence using vep. In order to do this, we need to change the row name a little bit:

# %%
mnv = mnv.key_by() #unkey first
mnv = mnv.rename({'locus' : 'snp2_locus', 'alleles' : 'snp2_alleles',"prev_locus":"locus", "prev_alleles":"alleles"}) #rename the snp1 locus and alleles as locus, allele
mnv = mnv.key_by('locus', 'alleles') #and re-key
mnv = hl.vep(mnv, vep_config, name="snp1_vep") #and vep
# Out:
# 2019-03-10 01:00:19 Hail: INFO: Coerced sorted dataset

# %% [markdown]
# Now let's see that the individual effects are correctly annotated by vep:

# %%
mnv.show(5) #check
# Out:
# 2019-03-10 01:01:03 Hail: INFO: Coerced sorted dataset
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | snp2_locus    | snp2_alleles | locus         | alleles    |  dist |       AF |    AC |
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | locus<GRCh37> | array<str>   | locus<GRCh37> | array<str> | int32 |  float64 | int32 |
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | 1:10506       | ["C","G"]    | 1:10505       | ["A","T"]  |     1 | 2.00e-04 |     1 |
# | 1:13118       | ["A","G"]    | 1:13116       | ["T","G"]  |     2 | 9.70e-02 |   486 |
# | 1:48328       | ["A","T"]    | 1:48327       | ["C","A"]  |     1 | 4.39e-03 |    22 |
# | 1:49989       | ["A","G"]    | 1:49988       | ["T","A"]  |     1 | 5.79e-03 |    29 |
# | 1:51049       | ["A","C"]    | 1:51047       | ["A","T"]  |     2 | 1.60e-03 |     8 |
# +---------------+--------------+---------------+------------+-------+----------+-------+
#
# +----------+----------+---------+--------------+----------+----------+----------+
# | filters  |  prev_AF | prev_AC | prev_filters | n_hethet | n_hethom | n_homhom |
# +----------+----------+---------+--------------+----------+----------+----------+
# | set<str> |  float64 |   int32 | set<str>     |    int64 |    int64 |    int64 |
# +----------+----------+---------+--------------+----------+----------+----------+
# | {}       | 2.00e-04 |       1 | {}           |        1 |        0 |        0 |
# | {}       | 9.70e-02 |     486 | {}           |      414 |       36 |        0 |
# | {}       | 4.39e-03 |      22 | {}           |       22 |        0 |        0 |
# | {}       | 5.79e-03 |      29 | {}           |       29 |        0 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# +----------+----------+---------+--------------+----------+----------+----------+
#
# +---------+------------------------+------------------------+--------------------+
# | n_total | snp2_vep.assembly_name | snp2_vep.allele_string | snp2_vep.ancestral |
# +---------+------------------------+------------------------+--------------------+
# |   int64 | str                    | str                    | str                |
# +---------+------------------------+------------------------+--------------------+
# |       1 | "GRCh37"               | "C/G"                  | NA                 |
# |     450 | "GRCh37"               | "A/G"                  | NA                 |
# |      22 | "GRCh37"               | "A/T"                  | NA                 |
# |      29 | "GRCh37"               | "A/G"                  | NA                 |
# |       8 | "GRCh37"               | "A/C"                  | NA                 |
# +---------+------------------------+------------------------+--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",0.00e+00,NA,NA,"C/G","G",8.00e-04,NA,10506,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("G",1.53e-01,NA,NA,"A/G","G",2.95e-02,NA,13118,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",1.36e-02,NA,48328,"T",1.40e-03,NA,NA,"T",3.00e-03,NA... |
# | [("G",1.00e-03,NA,NA,"A/G","G",1.74e-02,NA,49989,"G",1.40e-03,NA,NA,"G",4.00e-03,NA... |
# | [("C",0.00e+00,NA,NA,"A/C","C",0.00e+00,NA,51049,"C",0.00e+00,NA,NA,"C",3.00e-03,NA... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+---------------+-------------------------------+
# | snp2_vep.context | snp2_vep.end | snp2_vep.id   | snp2_vep.input                |
# +------------------+--------------+---------------+-------------------------------+
# | str              |        int32 | str           | str                           |
# +------------------+--------------+---------------+-------------------------------+
# | NA               |        10506 | "1_10506_C/G" | "1\t10506\t.\tC\tG\t.\t.\tGT" |
# | NA               |        13118 | "1_13118_A/G" | "1\t13118\t.\tA\tG\t.\t.\tGT" |
# | NA               |        48328 | "1_48328_A/T" | "1\t48328\t.\tA\tT\t.\t.\tGT" |
# | NA               |        49989 | "1_49989_A/G" | "1\t49989\t.\tA\tG\t.\t.\tGT" |
# | NA               |        51049 | "1_51049_A/C" | "1\t51049\t.\tA\tC\t.\t.\tGT" |
# +------------------+--------------+---------------+-------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------+
# | snp2_vep.most_severe_consequence |
# +----------------------------------+
# | str                              |
# +----------------------------------+
# | "upstream_gene_variant"          |
# | "intron_variant"                 |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# +----------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp2_vep.seq_region_name | snp2_vep.start | snp2_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          10506 |               1 |
# | "1"                      |          13118 |               1 |
# | "1"                      |          48328 |               1 |
# | "1"                      |          49989 |               1 |
# | "1"                      |          51049 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],38... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4721... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],3060... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2000... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+------------------------+------------------------+
# | snp2_vep.variant_class | snp1_vep.assembly_name | snp1_vep.allele_string |
# +------------------------+------------------------+------------------------+
# | str                    | str                    | str                    |
# +------------------------+------------------------+------------------------+
# | "SNV"                  | "GRCh37"               | "A/T"                  |
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "C/A"                  |
# | "SNV"                  | "GRCh37"               | "T/A"                  |
# | "SNV"                  | "GRCh37"               | "A/T"                  |
# +------------------------+------------------------+------------------------+
#
# +--------------------+
# | snp1_vep.ancestral |
# +--------------------+
# | str                |
# +--------------------+
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# +--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("T",0.00e+00,NA,NA,"A/T","T",8.00e-04,NA,10505,"T",0.00e+00,NA,NA,"T",0.00e+00,NA... |
# | [("G",1.53e-01,NA,NA,"T/G","G",2.95e-02,NA,13116,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("A",0.00e+00,NA,NA,"C/A","A",1.36e-02,NA,48327,"A",1.40e-03,NA,NA,"A",3.00e-03,NA... |
# | [("A",1.00e-03,NA,NA,"T/A","A",1.74e-02,NA,49988,"A",1.40e-03,NA,NA,"A",4.00e-03,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",0.00e+00,NA,51047,"T",0.00e+00,NA,NA,"T",3.00e-03,NA... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+---------------+-------------------------------+
# | snp1_vep.context | snp1_vep.end | snp1_vep.id   | snp1_vep.input                |
# +------------------+--------------+---------------+-------------------------------+
# | str              |        int32 | str           | str                           |
# +------------------+--------------+---------------+-------------------------------+
# | NA               |        10505 | "1_10505_A/T" | "1\t10505\t.\tA\tT\t.\t.\tGT" |
# | NA               |        13116 | "1_13116_T/G" | "1\t13116\t.\tT\tG\t.\t.\tGT" |
# | NA               |        48327 | "1_48327_C/A" | "1\t48327\t.\tC\tA\t.\t.\tGT" |
# | NA               |        49988 | "1_49988_T/A" | "1\t49988\t.\tT\tA\t.\t.\tGT" |
# | NA               |        51047 | "1_51047_A/T" | "1\t51047\t.\tA\tT\t.\t.\tGT" |
# +------------------+--------------+---------------+-------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------+
# | snp1_vep.most_severe_consequence |
# +----------------------------------+
# | str                              |
# +----------------------------------+
# | "upstream_gene_variant"          |
# | "intron_variant"                 |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# +----------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp1_vep.seq_region_name | snp1_vep.start | snp1_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          10505 |               1 |
# | "1"                      |          13116 |               1 |
# | "1"                      |          48327 |               1 |
# | "1"                      |          49988 |               1 |
# | "1"                      |          51047 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],38... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4722... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],3061... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2002... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+
# | snp1_vep.variant_class |
# +------------------------+
# | str                    |
# +------------------------+
# | "SNV"                  |
# | "SNV"                  |
# | "SNV"                  |
# | "SNV"                  |
# | "SNV"                  |
# +------------------------+
# showing top 5 rows

# %% [markdown]
# ## annotating the MNV effects
#
# This is still relatively straightforward, when the SNPs are next to each other, so let's focus on such MNVs first and do the annotation:

# %%
#let t1 be those with distance==1
t1 = mnv.filter(mnv.dist==1)
t1 = t1.annotate(refs=t1.alleles[0] +t1.snp2_alleles[0], alts=t1.alleles[1] +t1.snp2_alleles[1])# annotate combined refs, and alts
t1 = t1.annotate(mnv_alleles = [t1.refs,t1.alts]) #and let it be mnv_alleles
t1 = t1.key_by()#to re-key
t1 = t1.rename({'alleles' : 'snp1_alleles',"mnv_alleles":"alleles"}) #now the alleles is that of mnv (note. locus does not change. same as snp1)
t1 = t1.key_by('locus', 'alleles') #and re-key
t1 = hl.vep(t1, vep_config, name="mnv_vep")
# Out:
# 2019-03-10 01:07:34 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:07:34 Hail: INFO: Coerced sorted dataset

# %%
t1.show(5) #check
# Out:
# 2019-03-10 01:07:44 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:07:49 Hail: INFO: Coerced sorted dataset
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | snp2_locus    | snp2_alleles | locus         | snp1_alleles |  dist |       AF |    AC |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | locus<GRCh37> | array<str>   | locus<GRCh37> | array<str>   | int32 |  float64 | int32 |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | 1:10506       | ["C","G"]    | 1:10505       | ["A","T"]    |     1 | 2.00e-04 |     1 |
# | 1:48328       | ["A","T"]    | 1:48327       | ["C","A"]    |     1 | 4.39e-03 |    22 |
# | 1:49989       | ["A","G"]    | 1:49988       | ["T","A"]    |     1 | 5.79e-03 |    29 |
# | 1:51050       | ["A","T"]    | 1:51049       | ["A","C"]    |     1 | 1.60e-03 |     8 |
# | 1:55165       | ["A","G"]    | 1:55164       | ["C","A"]    |     1 | 2.00e-04 |     1 |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
#
# +----------+----------+---------+--------------+----------+----------+----------+
# | filters  |  prev_AF | prev_AC | prev_filters | n_hethet | n_hethom | n_homhom |
# +----------+----------+---------+--------------+----------+----------+----------+
# | set<str> |  float64 |   int32 | set<str>     |    int64 |    int64 |    int64 |
# +----------+----------+---------+--------------+----------+----------+----------+
# | {}       | 2.00e-04 |       1 | {}           |        1 |        0 |        0 |
# | {}       | 4.39e-03 |      22 | {}           |       22 |        0 |        0 |
# | {}       | 5.79e-03 |      29 | {}           |       29 |        0 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# | {}       | 9.23e-01 |    4624 | {}           |        0 |        0 |        1 |
# +----------+----------+---------+--------------+----------+----------+----------+
#
# +---------+------------------------+------------------------+--------------------+
# | n_total | snp2_vep.assembly_name | snp2_vep.allele_string | snp2_vep.ancestral |
# +---------+------------------------+------------------------+--------------------+
# |   int64 | str                    | str                    | str                |
# +---------+------------------------+------------------------+--------------------+
# |       1 | "GRCh37"               | "C/G"                  | NA                 |
# |      22 | "GRCh37"               | "A/T"                  | NA                 |
# |      29 | "GRCh37"               | "A/G"                  | NA                 |
# |       8 | "GRCh37"               | "A/T"                  | NA                 |
# |       1 | "GRCh37"               | "A/G"                  | NA                 |
# +---------+------------------------+------------------------+--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",0.00e+00,NA,NA,"C/G","G",8.00e-04,NA,10506,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",1.36e-02,NA,48328,"T",1.40e-03,NA,NA,"T",3.00e-03,NA... |
# | [("G",1.00e-03,NA,NA,"A/G","G",1.74e-02,NA,49989,"G",1.40e-03,NA,NA,"G",4.00e-03,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",0.00e+00,NA,51050,"T",0.00e+00,NA,NA,"T",3.00e-03,NA... |
# | [("G",0.00e+00,NA,NA,"A/G","G",8.00e-04,NA,55165,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+---------------+-------------------------------+
# | snp2_vep.context | snp2_vep.end | snp2_vep.id   | snp2_vep.input                |
# +------------------+--------------+---------------+-------------------------------+
# | str              |        int32 | str           | str                           |
# +------------------+--------------+---------------+-------------------------------+
# | NA               |        10506 | "1_10506_C/G" | "1\t10506\t.\tC\tG\t.\t.\tGT" |
# | NA               |        48328 | "1_48328_A/T" | "1\t48328\t.\tA\tT\t.\t.\tGT" |
# | NA               |        49989 | "1_49989_A/G" | "1\t49989\t.\tA\tG\t.\t.\tGT" |
# | NA               |        51050 | "1_51050_A/T" | "1\t51050\t.\tA\tT\t.\t.\tGT" |
# | NA               |        55165 | "1_55165_A/G" | "1\t55165\t.\tA\tG\t.\t.\tGT" |
# +------------------+--------------+---------------+-------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------+
# | snp2_vep.most_severe_consequence |
# +----------------------------------+
# | str                              |
# +----------------------------------+
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "downstream_gene_variant"        |
# +----------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp2_vep.seq_region_name | snp2_vep.start | snp2_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          10506 |               1 |
# | "1"                      |          48328 |               1 |
# | "1"                      |          49989 |               1 |
# | "1"                      |          51050 |               1 |
# | "1"                      |          55165 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],38... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4721... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],3060... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1999... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],22... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+------------------------+------------------------+
# | snp2_vep.variant_class | snp1_vep.assembly_name | snp1_vep.allele_string |
# +------------------------+------------------------+------------------------+
# | str                    | str                    | str                    |
# +------------------------+------------------------+------------------------+
# | "SNV"                  | "GRCh37"               | "A/T"                  |
# | "SNV"                  | "GRCh37"               | "C/A"                  |
# | "SNV"                  | "GRCh37"               | "T/A"                  |
# | "SNV"                  | "GRCh37"               | "A/C"                  |
# | "SNV"                  | "GRCh37"               | "C/A"                  |
# +------------------------+------------------------+------------------------+
#
# +--------------------+
# | snp1_vep.ancestral |
# +--------------------+
# | str                |
# +--------------------+
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# +--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("T",0.00e+00,NA,NA,"A/T","T",8.00e-04,NA,10505,"T",0.00e+00,NA,NA,"T",0.00e+00,NA... |
# | [("A",0.00e+00,NA,NA,"C/A","A",1.36e-02,NA,48327,"A",1.40e-03,NA,NA,"A",3.00e-03,NA... |
# | [("A",1.00e-03,NA,NA,"T/A","A",1.74e-02,NA,49988,"A",1.40e-03,NA,NA,"A",4.00e-03,NA... |
# | [("C",0.00e+00,NA,NA,"A/C","C",0.00e+00,NA,51049,"C",0.00e+00,NA,NA,"C",3.00e-03,NA... |
# | [("A",9.86e-01,NA,NA,"C/A","A",7.43e-01,NA,55164,"A",9.64e-01,NA,NA,"A",1.00e+00,NA... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+---------------+-------------------------------+
# | snp1_vep.context | snp1_vep.end | snp1_vep.id   | snp1_vep.input                |
# +------------------+--------------+---------------+-------------------------------+
# | str              |        int32 | str           | str                           |
# +------------------+--------------+---------------+-------------------------------+
# | NA               |        10505 | "1_10505_A/T" | "1\t10505\t.\tA\tT\t.\t.\tGT" |
# | NA               |        48327 | "1_48327_C/A" | "1\t48327\t.\tC\tA\t.\t.\tGT" |
# | NA               |        49988 | "1_49988_T/A" | "1\t49988\t.\tT\tA\t.\t.\tGT" |
# | NA               |        51049 | "1_51049_A/C" | "1\t51049\t.\tA\tC\t.\t.\tGT" |
# | NA               |        55164 | "1_55164_C/A" | "1\t55164\t.\tC\tA\t.\t.\tGT" |
# +------------------+--------------+---------------+-------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------+
# | snp1_vep.most_severe_consequence |
# +----------------------------------+
# | str                              |
# +----------------------------------+
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "upstream_gene_variant"          |
# | "downstream_gene_variant"        |
# +----------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp1_vep.seq_region_name | snp1_vep.start | snp1_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          10505 |               1 |
# | "1"                      |          48327 |               1 |
# | "1"                      |          49988 |               1 |
# | "1"                      |          51049 |               1 |
# | "1"                      |          55164 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],38... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4722... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],3061... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2000... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],22... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+------+------+-------------+-----------------------+
# | snp1_vep.variant_class | refs | alts | alleles     | mnv_vep.assembly_name |
# +------------------------+------+------+-------------+-----------------------+
# | str                    | str  | str  | array<str>  | str                   |
# +------------------------+------+------+-------------+-----------------------+
# | "SNV"                  | "AC" | "TG" | ["AC","TG"] | "GRCh37"              |
# | "SNV"                  | "CA" | "AT" | ["CA","AT"] | "GRCh37"              |
# | "SNV"                  | "TA" | "AG" | ["TA","AG"] | "GRCh37"              |
# | "SNV"                  | "AA" | "CT" | ["AA","CT"] | "GRCh37"              |
# | "SNV"                  | "CA" | "AG" | ["CA","AG"] | "GRCh37"              |
# +------------------------+------+------+-------------+-----------------------+
#
# +-----------------------+-------------------+
# | mnv_vep.allele_string | mnv_vep.ancestral |
# +-----------------------+-------------------+
# | str                   | str               |
# +-----------------------+-------------------+
# | "AC/TG"               | NA                |
# | "CA/AT"               | NA                |
# | "TA/AG"               | NA                |
# | "AA/CT"               | NA                |
# | "CA/AG"               | NA                |
# +-----------------------+-------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.colocated_variants                                                             |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +-----------------+-------------+-----------------+---------------------------------+
# | mnv_vep.context | mnv_vep.end | mnv_vep.id      | mnv_vep.input                   |
# +-----------------+-------------+-----------------+---------------------------------+
# | str             |       int32 | str             | str                             |
# +-----------------+-------------+-----------------+---------------------------------+
# | NA              |       10506 | "1_10505_AC/TG" | "1\t10505\t.\tAC\tTG\t.\t.\tGT" |
# | NA              |       48328 | "1_48327_CA/AT" | "1\t48327\t.\tCA\tAT\t.\t.\tGT" |
# | NA              |       49989 | "1_49988_TA/AG" | "1\t49988\t.\tTA\tAG\t.\t.\tGT" |
# | NA              |       51050 | "1_51049_AA/CT" | "1\t51049\t.\tAA\tCT\t.\t.\tGT" |
# | NA              |       55165 | "1_55164_CA/AG" | "1\t55164\t.\tCA\tAG\t.\t.\tGT" |
# +-----------------+-------------+-----------------+---------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.intergenic_consequences                                                        |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +---------------------------------+
# | mnv_vep.most_severe_consequence |
# +---------------------------------+
# | str                             |
# +---------------------------------+
# | "upstream_gene_variant"         |
# | "upstream_gene_variant"         |
# | "upstream_gene_variant"         |
# | "upstream_gene_variant"         |
# | "downstream_gene_variant"       |
# +---------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.motif_feature_consequences                                                     |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.regulatory_feature_consequences                                                |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +-------------------------+---------------+----------------+
# | mnv_vep.seq_region_name | mnv_vep.start | mnv_vep.strand |
# +-------------------------+---------------+----------------+
# | str                     |         int32 |          int32 |
# +-------------------------+---------------+----------------+
# | "1"                     |         10505 |              1 |
# | "1"                     |         48327 |              1 |
# | "1"                     |         49988 |              1 |
# | "1"                     |         51049 |              1 |
# | "1"                     |         55164 |              1 |
# +-------------------------+---------------+----------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.transcript_consequences                                                        |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],38... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4721... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],3060... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1999... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],22... |
# +----------------------------------------------------------------------------------------+
#
# +-----------------------+
# | mnv_vep.variant_class |
# +-----------------------+
# | str                   |
# +-----------------------+
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# +-----------------------+
# showing top 5 rows

# %% [markdown]
# When the SNPs are not to each other, it is a bit not straightforward because you need to fill the reference base pair that are in between,
# in order to pass to vep.
# Fortunately, our nice hail also allows us to do that. The first step is to load the reference genome:

# %%
grch37 = hl.get_reference('GRCh37')
grch37_fasta = 'gs://hail-common/references/human_g1k_v37.fasta.gz'
grch37_fai = 'gs://hail-common/references/human_g1k_v37.fasta.fai'
grch37.add_sequence(grch37_fasta, grch37_fai)

# %% [markdown]
# Then we can fill the context using `sequence_context`:

# %%
t2 = mnv.filter(mnv.dist==2)
t2 = t2.annotate(refs = t2.alleles[0] + t2.locus.sequence_context(before=-1, after=1) + t2.snp2_alleles[0],
                           alts = t2.alleles[1] + t2.locus.sequence_context(before=-1, after=1) + t2.snp2_alleles[1]) #fill the one reference sequence after the snp1

# %%
t2.show()
# Out:
# 2019-03-10 02:01:48 Hail: INFO: Coerced sorted dataset
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | snp2_locus    | snp2_alleles | locus         | alleles    |  dist |       AF |    AC |
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | locus<GRCh37> | array<str>   | locus<GRCh37> | array<str> | int32 |  float64 | int32 |
# +---------------+--------------+---------------+------------+-------+----------+-------+
# | 1:13118       | ["A","G"]    | 1:13116       | ["T","G"]  |     2 | 9.70e-02 |   486 |
# | 1:51049       | ["A","C"]    | 1:51047       | ["A","T"]  |     2 | 1.60e-03 |     8 |
# | 1:57264       | ["T","G"]    | 1:57262       | ["T","G"]  |     2 | 1.40e-03 |     7 |
# | 1:74792       | ["G","A"]    | 1:74790       | ["C","G"]  |     2 | 3.77e-02 |   189 |
# | 1:362907      | ["G","C"]    | 1:362905      | ["T","G"]  |     2 | 2.18e-02 |   109 |
# | 1:559985      | ["C","T"]    | 1:559983      | ["C","T"]  |     2 | 1.40e-02 |    70 |
# | 1:564862      | ["T","C"]    | 1:564860      | ["A","G"]  |     2 | 5.19e-02 |   260 |
# | 1:565006      | ["T","C"]    | 1:565004      | ["T","A"]  |     2 | 3.86e-01 |  1931 |
# | 1:565937      | ["T","C"]    | 1:565935      | ["C","T"]  |     2 | 3.93e-02 |   197 |
# | 1:568938      | ["A","G"]    | 1:568936      | ["G","A"]  |     2 | 2.20e-03 |    11 |
# +---------------+--------------+---------------+------------+-------+----------+-------+
#
# +----------+----------+---------+--------------+----------+----------+----------+
# | filters  |  prev_AF | prev_AC | prev_filters | n_hethet | n_hethom | n_homhom |
# +----------+----------+---------+--------------+----------+----------+----------+
# | set<str> |  float64 |   int32 | set<str>     |    int64 |    int64 |    int64 |
# +----------+----------+---------+--------------+----------+----------+----------+
# | {}       | 9.70e-02 |     486 | {}           |      414 |       36 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# | {}       | 1.40e-03 |       7 | {}           |        7 |        0 |        0 |
# | {}       | 3.77e-02 |     189 | {}           |      187 |        1 |        0 |
# | {}       | 1.26e-01 |     633 | {}           |        8 |        0 |        0 |
# | {}       | 4.39e-03 |      22 | {}           |       17 |        0 |        1 |
# | {}       | 3.99e-04 |       2 | {}           |        0 |        0 |        1 |
# | {}       | 9.98e-04 |       5 | {}           |        0 |        1 |        1 |
# | {}       | 6.33e-02 |     317 | {}           |        3 |        0 |        0 |
# | {}       | 3.99e-03 |      20 | {}           |        2 |        3 |        0 |
# +----------+----------+---------+--------------+----------+----------+----------+
#
# +---------+------------------------+------------------------+--------------------+
# | n_total | snp2_vep.assembly_name | snp2_vep.allele_string | snp2_vep.ancestral |
# +---------+------------------------+------------------------+--------------------+
# |   int64 | str                    | str                    | str                |
# +---------+------------------------+------------------------+--------------------+
# |     450 | "GRCh37"               | "A/G"                  | NA                 |
# |       8 | "GRCh37"               | "A/C"                  | NA                 |
# |       7 | "GRCh37"               | "T/G"                  | NA                 |
# |     188 | "GRCh37"               | "G/A"                  | NA                 |
# |       8 | "GRCh37"               | "G/C"                  | NA                 |
# |      18 | "GRCh37"               | "C/T"                  | NA                 |
# |       1 | "GRCh37"               | "T/C"                  | NA                 |
# |       2 | "GRCh37"               | "T/C"                  | NA                 |
# |       3 | "GRCh37"               | "T/C"                  | NA                 |
# |       5 | "GRCh37"               | "A/G"                  | NA                 |
# +---------+------------------------+------------------------+--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",1.53e-01,NA,NA,"A/G","G",2.95e-02,NA,13118,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("C",0.00e+00,NA,NA,"A/C","C",0.00e+00,NA,51049,"C",0.00e+00,NA,NA,"C",3.00e-03,NA... |
# | [("G",7.20e-03,NA,NA,"T/G","G",0.00e+00,NA,57264,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("A",2.15e-02,NA,NA,"G/A","A",7.56e-02,NA,74792,"A",4.90e-02,NA,NA,"A",8.90e-03,NA... |
# | [("C",1.00e-03,NA,NA,"G/C","C",7.79e-02,NA,362907,"C",4.30e-03,NA,NA,"C",2.00e-03,N... |
# | [("T",1.23e-02,NA,NA,"C/T","T",2.72e-02,NA,559985,"T",1.15e-02,NA,NA,"T",6.90e-03,N... |
# | [("C",7.20e-03,NA,NA,"T/C","C",1.23e-01,NA,564862,"C",1.30e-02,NA,NA,"C",3.67e-02,N... |
# | [("C",2.25e-01,NA,NA,"T/C","C",5.64e-01,NA,565006,"C",2.70e-01,NA,NA,"C",3.78e-01,N... |
# | [("C",1.43e-02,NA,NA,"T/C","C",8.77e-02,NA,565937,"C",7.20e-03,NA,NA,"C",3.77e-02,N... |
# | [("G",2.00e-03,NA,NA,"A/G","G",6.10e-03,NA,568938,"G",1.40e-03,NA,NA,"G",0.00e+00,N... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+----------------+--------------------------------+
# | snp2_vep.context | snp2_vep.end | snp2_vep.id    | snp2_vep.input                 |
# +------------------+--------------+----------------+--------------------------------+
# | str              |        int32 | str            | str                            |
# +------------------+--------------+----------------+--------------------------------+
# | NA               |        13118 | "1_13118_A/G"  | "1\t13118\t.\tA\tG\t.\t.\tGT"  |
# | NA               |        51049 | "1_51049_A/C"  | "1\t51049\t.\tA\tC\t.\t.\tGT"  |
# | NA               |        57264 | "1_57264_T/G"  | "1\t57264\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        74792 | "1_74792_G/A"  | "1\t74792\t.\tG\tA\t.\t.\tGT"  |
# | NA               |       362907 | "1_362907_G/C" | "1\t362907\t.\tG\tC\t.\t.\tGT" |
# | NA               |       559985 | "1_559985_C/T" | "1\t559985\t.\tC\tT\t.\t.\tGT" |
# | NA               |       564862 | "1_564862_T/C" | "1\t564862\t.\tT\tC\t.\t.\tGT" |
# | NA               |       565006 | "1_565006_T/C" | "1\t565006\t.\tT\tC\t.\t.\tGT" |
# | NA               |       565937 | "1_565937_T/C" | "1\t565937\t.\tT\tC\t.\t.\tGT" |
# | NA               |       568938 | "1_568938_A/G" | "1\t568938\t.\tA\tG\t.\t.\tGT" |
# +------------------+--------------+----------------+--------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------------------+
# | snp2_vep.most_severe_consequence     |
# +--------------------------------------+
# | str                                  |
# +--------------------------------------+
# | "intron_variant"                     |
# | "upstream_gene_variant"              |
# | "downstream_gene_variant"            |
# | "downstream_gene_variant"            |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "non_coding_transcript_exon_variant" |
# | "non_coding_transcript_exon_variant" |
# +--------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp2_vep.seq_region_name | snp2_vep.start | snp2_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          13118 |               1 |
# | "1"                      |          51049 |               1 |
# | "1"                      |          57264 |               1 |
# | "1"                      |          74792 |               1 |
# | "1"                      |         362907 |               1 |
# | "1"                      |         559985 |               1 |
# | "1"                      |         564862 |               1 |
# | "1"                      |         565006 |               1 |
# | "1"                      |         565937 |               1 |
# | "1"                      |         568938 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2000... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],23... |
# | [(1,NA,"protein_coding",1,"CCDS30547.1",NA,NA,NA,NA,NA,["downstream_gene_variant"],... |
# | [(1,NA,"protein_coding",1,"CCDS41220.1",NA,NA,NA,NA,NA,["upstream_gene_variant"],47... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4457,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1592,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1448,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],517,N... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],942... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+------------------------+------------------------+
# | snp2_vep.variant_class | snp1_vep.assembly_name | snp1_vep.allele_string |
# +------------------------+------------------------+------------------------+
# | str                    | str                    | str                    |
# +------------------------+------------------------+------------------------+
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "A/T"                  |
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "C/G"                  |
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "C/T"                  |
# | "SNV"                  | "GRCh37"               | "A/G"                  |
# | "SNV"                  | "GRCh37"               | "T/A"                  |
# | "SNV"                  | "GRCh37"               | "C/T"                  |
# | "SNV"                  | "GRCh37"               | "G/A"                  |
# +------------------------+------------------------+------------------------+
#
# +--------------------+
# | snp1_vep.ancestral |
# +--------------------+
# | str                |
# +--------------------+
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# +--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",1.53e-01,NA,NA,"T/G","G",2.95e-02,NA,13116,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",0.00e+00,NA,51047,"T",0.00e+00,NA,NA,"T",3.00e-03,NA... |
# | [("G",7.20e-03,NA,NA,"T/G","G",0.00e+00,NA,57262,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("G",2.15e-02,NA,NA,"C/G","G",7.56e-02,NA,74790,"G",4.90e-02,NA,NA,"G",8.90e-03,NA... |
# | [("G",4.60e-02,NA,NA,"T/G","G",3.34e-01,NA,362905,"G",6.92e-02,NA,NA,"G",4.86e-02,N... |
# | [("T",1.00e-03,NA,NA,"C/T","T",1.13e-02,NA,559983,"T",8.60e-03,NA,NA,"T",0.00e+00,N... |
# | [("G",0.00e+00,NA,NA,"A/G","G",1.50e-03,NA,564860,"G",0.00e+00,NA,NA,"G",0.00e+00,N... |
# | [("A",0.00e+00,NA,NA,"T/A","A",3.80e-03,NA,565004,"A",0.00e+00,NA,NA,"A",0.00e+00,N... |
# | [("T",4.29e-02,NA,NA,"C/T","T",1.76e-01,NA,565935,"T",2.74e-02,NA,NA,"T",0.00e+00,N... |
# | [("A",0.00e+00,NA,NA,"G/A","A",1.44e-02,NA,568936,"A",1.40e-03,NA,NA,"A",0.00e+00,N... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+----------------+--------------------------------+
# | snp1_vep.context | snp1_vep.end | snp1_vep.id    | snp1_vep.input                 |
# +------------------+--------------+----------------+--------------------------------+
# | str              |        int32 | str            | str                            |
# +------------------+--------------+----------------+--------------------------------+
# | NA               |        13116 | "1_13116_T/G"  | "1\t13116\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        51047 | "1_51047_A/T"  | "1\t51047\t.\tA\tT\t.\t.\tGT"  |
# | NA               |        57262 | "1_57262_T/G"  | "1\t57262\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        74790 | "1_74790_C/G"  | "1\t74790\t.\tC\tG\t.\t.\tGT"  |
# | NA               |       362905 | "1_362905_T/G" | "1\t362905\t.\tT\tG\t.\t.\tGT" |
# | NA               |       559983 | "1_559983_C/T" | "1\t559983\t.\tC\tT\t.\t.\tGT" |
# | NA               |       564860 | "1_564860_A/G" | "1\t564860\t.\tA\tG\t.\t.\tGT" |
# | NA               |       565004 | "1_565004_T/A" | "1\t565004\t.\tT\tA\t.\t.\tGT" |
# | NA               |       565935 | "1_565935_C/T" | "1\t565935\t.\tC\tT\t.\t.\tGT" |
# | NA               |       568936 | "1_568936_G/A" | "1\t568936\t.\tG\tA\t.\t.\tGT" |
# +------------------+--------------+----------------+--------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------------------+
# | snp1_vep.most_severe_consequence     |
# +--------------------------------------+
# | str                                  |
# +--------------------------------------+
# | "intron_variant"                     |
# | "upstream_gene_variant"              |
# | "downstream_gene_variant"            |
# | "downstream_gene_variant"            |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "non_coding_transcript_exon_variant" |
# | "non_coding_transcript_exon_variant" |
# +--------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp1_vep.seq_region_name | snp1_vep.start | snp1_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          13116 |               1 |
# | "1"                      |          51047 |               1 |
# | "1"                      |          57262 |               1 |
# | "1"                      |          74790 |               1 |
# | "1"                      |         362905 |               1 |
# | "1"                      |         559983 |               1 |
# | "1"                      |         564860 |               1 |
# | "1"                      |         565004 |               1 |
# | "1"                      |         565935 |               1 |
# | "1"                      |         568936 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2002... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],23... |
# | [(1,NA,"protein_coding",1,"CCDS30547.1",NA,NA,NA,NA,NA,["downstream_gene_variant"],... |
# | [(1,NA,"protein_coding",1,"CCDS41220.1",NA,NA,NA,NA,NA,["upstream_gene_variant"],47... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4459,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1594,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1450,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],519,N... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],940... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+-------+-------+
# | snp1_vep.variant_class | refs  | alts  |
# +------------------------+-------+-------+
# | str                    | str   | str   |
# +------------------------+-------+-------+
# | "SNV"                  | "TGA" | "GGG" |
# | "SNV"                  | "ATA" | "TTC" |
# | "SNV"                  | "TAT" | "GAG" |
# | "SNV"                  | "CTG" | "GTA" |
# | "SNV"                  | "TGG" | "GGC" |
# | "SNV"                  | "CGC" | "TGT" |
# | "SNV"                  | "AGT" | "GGC" |
# | "SNV"                  | "TAT" | "AAC" |
# | "SNV"                  | "CCT" | "TCC" |
# | "SNV"                  | "GTA" | "ATG" |
# +------------------------+-------+-------+
# showing top 10 rows

# %% [markdown]
# And we are good to go!

# %%
t2 = t2.annotate(mnv_alleles = [t2.refs,t2.alts]) #and let it be mnv_alleles
t2 = t2.key_by()#to re-key
t2 = t2.rename({'alleles' : 'snp1_alleles',"mnv_alleles":"alleles"}) #now the alleles is that of mnv (note. locus does not change. same as snp1)
t2 = t2.key_by('locus', 'alleles') #and re-key
t2 = hl.vep(t2, vep_config, name="mnv_vep", block_size=10)
# Out:
# 2019-03-10 02:02:48 Hail: INFO: Coerced sorted dataset
# 2019-03-10 02:02:48 Hail: INFO: Coerced sorted dataset

# %%
t2.show()
# Out:
# 2019-03-10 02:02:57 Hail: INFO: Coerced sorted dataset
# 2019-03-10 02:02:58 Hail: INFO: Coerced sorted dataset
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | snp2_locus    | snp2_alleles | locus         | snp1_alleles |  dist |       AF |    AC |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | locus<GRCh37> | array<str>   | locus<GRCh37> | array<str>   | int32 |  float64 | int32 |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
# | 1:13118       | ["A","G"]    | 1:13116       | ["T","G"]    |     2 | 9.70e-02 |   486 |
# | 1:51049       | ["A","C"]    | 1:51047       | ["A","T"]    |     2 | 1.60e-03 |     8 |
# | 1:57264       | ["T","G"]    | 1:57262       | ["T","G"]    |     2 | 1.40e-03 |     7 |
# | 1:74792       | ["G","A"]    | 1:74790       | ["C","G"]    |     2 | 3.77e-02 |   189 |
# | 1:362907      | ["G","C"]    | 1:362905      | ["T","G"]    |     2 | 2.18e-02 |   109 |
# | 1:559985      | ["C","T"]    | 1:559983      | ["C","T"]    |     2 | 1.40e-02 |    70 |
# | 1:564862      | ["T","C"]    | 1:564860      | ["A","G"]    |     2 | 5.19e-02 |   260 |
# | 1:565006      | ["T","C"]    | 1:565004      | ["T","A"]    |     2 | 3.86e-01 |  1931 |
# | 1:565937      | ["T","C"]    | 1:565935      | ["C","T"]    |     2 | 3.93e-02 |   197 |
# | 1:568938      | ["A","G"]    | 1:568936      | ["G","A"]    |     2 | 2.20e-03 |    11 |
# +---------------+--------------+---------------+--------------+-------+----------+-------+
#
# +----------+----------+---------+--------------+----------+----------+----------+
# | filters  |  prev_AF | prev_AC | prev_filters | n_hethet | n_hethom | n_homhom |
# +----------+----------+---------+--------------+----------+----------+----------+
# | set<str> |  float64 |   int32 | set<str>     |    int64 |    int64 |    int64 |
# +----------+----------+---------+--------------+----------+----------+----------+
# | {}       | 9.70e-02 |     486 | {}           |      414 |       36 |        0 |
# | {}       | 1.60e-03 |       8 | {}           |        8 |        0 |        0 |
# | {}       | 1.40e-03 |       7 | {}           |        7 |        0 |        0 |
# | {}       | 3.77e-02 |     189 | {}           |      187 |        1 |        0 |
# | {}       | 1.26e-01 |     633 | {}           |        8 |        0 |        0 |
# | {}       | 4.39e-03 |      22 | {}           |       17 |        0 |        1 |
# | {}       | 3.99e-04 |       2 | {}           |        0 |        0 |        1 |
# | {}       | 9.98e-04 |       5 | {}           |        0 |        1 |        1 |
# | {}       | 6.33e-02 |     317 | {}           |        3 |        0 |        0 |
# | {}       | 3.99e-03 |      20 | {}           |        2 |        3 |        0 |
# +----------+----------+---------+--------------+----------+----------+----------+
#
# +---------+------------------------+------------------------+--------------------+
# | n_total | snp2_vep.assembly_name | snp2_vep.allele_string | snp2_vep.ancestral |
# +---------+------------------------+------------------------+--------------------+
# |   int64 | str                    | str                    | str                |
# +---------+------------------------+------------------------+--------------------+
# |     450 | "GRCh37"               | "A/G"                  | NA                 |
# |       8 | "GRCh37"               | "A/C"                  | NA                 |
# |       7 | "GRCh37"               | "T/G"                  | NA                 |
# |     188 | "GRCh37"               | "G/A"                  | NA                 |
# |       8 | "GRCh37"               | "G/C"                  | NA                 |
# |      18 | "GRCh37"               | "C/T"                  | NA                 |
# |       1 | "GRCh37"               | "T/C"                  | NA                 |
# |       2 | "GRCh37"               | "T/C"                  | NA                 |
# |       3 | "GRCh37"               | "T/C"                  | NA                 |
# |       5 | "GRCh37"               | "A/G"                  | NA                 |
# +---------+------------------------+------------------------+--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",1.53e-01,NA,NA,"A/G","G",2.95e-02,NA,13118,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("C",0.00e+00,NA,NA,"A/C","C",0.00e+00,NA,51049,"C",0.00e+00,NA,NA,"C",3.00e-03,NA... |
# | [("G",7.20e-03,NA,NA,"T/G","G",0.00e+00,NA,57264,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("A",2.15e-02,NA,NA,"G/A","A",7.56e-02,NA,74792,"A",4.90e-02,NA,NA,"A",8.90e-03,NA... |
# | [("C",1.00e-03,NA,NA,"G/C","C",7.79e-02,NA,362907,"C",4.30e-03,NA,NA,"C",2.00e-03,N... |
# | [("T",1.23e-02,NA,NA,"C/T","T",2.72e-02,NA,559985,"T",1.15e-02,NA,NA,"T",6.90e-03,N... |
# | [("C",7.20e-03,NA,NA,"T/C","C",1.23e-01,NA,564862,"C",1.30e-02,NA,NA,"C",3.67e-02,N... |
# | [("C",2.25e-01,NA,NA,"T/C","C",5.64e-01,NA,565006,"C",2.70e-01,NA,NA,"C",3.78e-01,N... |
# | [("C",1.43e-02,NA,NA,"T/C","C",8.77e-02,NA,565937,"C",7.20e-03,NA,NA,"C",3.77e-02,N... |
# | [("G",2.00e-03,NA,NA,"A/G","G",6.10e-03,NA,568938,"G",1.40e-03,NA,NA,"G",0.00e+00,N... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+----------------+--------------------------------+
# | snp2_vep.context | snp2_vep.end | snp2_vep.id    | snp2_vep.input                 |
# +------------------+--------------+----------------+--------------------------------+
# | str              |        int32 | str            | str                            |
# +------------------+--------------+----------------+--------------------------------+
# | NA               |        13118 | "1_13118_A/G"  | "1\t13118\t.\tA\tG\t.\t.\tGT"  |
# | NA               |        51049 | "1_51049_A/C"  | "1\t51049\t.\tA\tC\t.\t.\tGT"  |
# | NA               |        57264 | "1_57264_T/G"  | "1\t57264\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        74792 | "1_74792_G/A"  | "1\t74792\t.\tG\tA\t.\t.\tGT"  |
# | NA               |       362907 | "1_362907_G/C" | "1\t362907\t.\tG\tC\t.\t.\tGT" |
# | NA               |       559985 | "1_559985_C/T" | "1\t559985\t.\tC\tT\t.\t.\tGT" |
# | NA               |       564862 | "1_564862_T/C" | "1\t564862\t.\tT\tC\t.\t.\tGT" |
# | NA               |       565006 | "1_565006_T/C" | "1\t565006\t.\tT\tC\t.\t.\tGT" |
# | NA               |       565937 | "1_565937_T/C" | "1\t565937\t.\tT\tC\t.\t.\tGT" |
# | NA               |       568938 | "1_568938_A/G" | "1\t568938\t.\tA\tG\t.\t.\tGT" |
# +------------------+--------------+----------------+--------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------------------+
# | snp2_vep.most_severe_consequence     |
# +--------------------------------------+
# | str                                  |
# +--------------------------------------+
# | "intron_variant"                     |
# | "upstream_gene_variant"              |
# | "downstream_gene_variant"            |
# | "downstream_gene_variant"            |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "non_coding_transcript_exon_variant" |
# | "non_coding_transcript_exon_variant" |
# +--------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp2_vep.seq_region_name | snp2_vep.start | snp2_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          13118 |               1 |
# | "1"                      |          51049 |               1 |
# | "1"                      |          57264 |               1 |
# | "1"                      |          74792 |               1 |
# | "1"                      |         362907 |               1 |
# | "1"                      |         559985 |               1 |
# | "1"                      |         564862 |               1 |
# | "1"                      |         565006 |               1 |
# | "1"                      |         565937 |               1 |
# | "1"                      |         568938 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2000... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],23... |
# | [(1,NA,"protein_coding",1,"CCDS30547.1",NA,NA,NA,NA,NA,["downstream_gene_variant"],... |
# | [(1,NA,"protein_coding",1,"CCDS41220.1",NA,NA,NA,NA,NA,["upstream_gene_variant"],47... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4457,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1592,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1448,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],517,N... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],942... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+------------------------+------------------------+
# | snp2_vep.variant_class | snp1_vep.assembly_name | snp1_vep.allele_string |
# +------------------------+------------------------+------------------------+
# | str                    | str                    | str                    |
# +------------------------+------------------------+------------------------+
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "A/T"                  |
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "C/G"                  |
# | "SNV"                  | "GRCh37"               | "T/G"                  |
# | "SNV"                  | "GRCh37"               | "C/T"                  |
# | "SNV"                  | "GRCh37"               | "A/G"                  |
# | "SNV"                  | "GRCh37"               | "T/A"                  |
# | "SNV"                  | "GRCh37"               | "C/T"                  |
# | "SNV"                  | "GRCh37"               | "G/A"                  |
# +------------------------+------------------------+------------------------+
#
# +--------------------+
# | snp1_vep.ancestral |
# +--------------------+
# | str                |
# +--------------------+
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# | NA                 |
# +--------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.colocated_variants                                                            |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | [("G",1.53e-01,NA,NA,"T/G","G",2.95e-02,NA,13116,"G",1.21e-01,NA,NA,"G",2.48e-02,NA... |
# | [("T",0.00e+00,NA,NA,"A/T","T",0.00e+00,NA,51047,"T",0.00e+00,NA,NA,"T",3.00e-03,NA... |
# | [("G",7.20e-03,NA,NA,"T/G","G",0.00e+00,NA,57262,"G",0.00e+00,NA,NA,"G",0.00e+00,NA... |
# | [("G",2.15e-02,NA,NA,"C/G","G",7.56e-02,NA,74790,"G",4.90e-02,NA,NA,"G",8.90e-03,NA... |
# | [("G",4.60e-02,NA,NA,"T/G","G",3.34e-01,NA,362905,"G",6.92e-02,NA,NA,"G",4.86e-02,N... |
# | [("T",1.00e-03,NA,NA,"C/T","T",1.13e-02,NA,559983,"T",8.60e-03,NA,NA,"T",0.00e+00,N... |
# | [("G",0.00e+00,NA,NA,"A/G","G",1.50e-03,NA,564860,"G",0.00e+00,NA,NA,"G",0.00e+00,N... |
# | [("A",0.00e+00,NA,NA,"T/A","A",3.80e-03,NA,565004,"A",0.00e+00,NA,NA,"A",0.00e+00,N... |
# | [("T",4.29e-02,NA,NA,"C/T","T",1.76e-01,NA,565935,"T",2.74e-02,NA,NA,"T",0.00e+00,N... |
# | [("A",0.00e+00,NA,NA,"G/A","A",1.44e-02,NA,568936,"A",1.40e-03,NA,NA,"A",0.00e+00,N... |
# +----------------------------------------------------------------------------------------+
#
# +------------------+--------------+----------------+--------------------------------+
# | snp1_vep.context | snp1_vep.end | snp1_vep.id    | snp1_vep.input                 |
# +------------------+--------------+----------------+--------------------------------+
# | str              |        int32 | str            | str                            |
# +------------------+--------------+----------------+--------------------------------+
# | NA               |        13116 | "1_13116_T/G"  | "1\t13116\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        51047 | "1_51047_A/T"  | "1\t51047\t.\tA\tT\t.\t.\tGT"  |
# | NA               |        57262 | "1_57262_T/G"  | "1\t57262\t.\tT\tG\t.\t.\tGT"  |
# | NA               |        74790 | "1_74790_C/G"  | "1\t74790\t.\tC\tG\t.\t.\tGT"  |
# | NA               |       362905 | "1_362905_T/G" | "1\t362905\t.\tT\tG\t.\t.\tGT" |
# | NA               |       559983 | "1_559983_C/T" | "1\t559983\t.\tC\tT\t.\t.\tGT" |
# | NA               |       564860 | "1_564860_A/G" | "1\t564860\t.\tA\tG\t.\t.\tGT" |
# | NA               |       565004 | "1_565004_T/A" | "1\t565004\t.\tT\tA\t.\t.\tGT" |
# | NA               |       565935 | "1_565935_C/T" | "1\t565935\t.\tC\tT\t.\t.\tGT" |
# | NA               |       568936 | "1_568936_G/A" | "1\t568936\t.\tG\tA\t.\t.\tGT" |
# +------------------+--------------+----------------+--------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.intergenic_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------------------+
# | snp1_vep.most_severe_consequence     |
# +--------------------------------------+
# | str                                  |
# +--------------------------------------+
# | "intron_variant"                     |
# | "upstream_gene_variant"              |
# | "downstream_gene_variant"            |
# | "downstream_gene_variant"            |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "non_coding_transcript_exon_variant" |
# | "non_coding_transcript_exon_variant" |
# +--------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.motif_feature_consequences                                                    |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.regulatory_feature_consequences                                               |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------+----------------+-----------------+
# | snp1_vep.seq_region_name | snp1_vep.start | snp1_vep.strand |
# +--------------------------+----------------+-----------------+
# | str                      |          int32 |           int32 |
# +--------------------------+----------------+-----------------+
# | "1"                      |          13116 |               1 |
# | "1"                      |          51047 |               1 |
# | "1"                      |          57262 |               1 |
# | "1"                      |          74790 |               1 |
# | "1"                      |         362905 |               1 |
# | "1"                      |         559983 |               1 |
# | "1"                      |         564860 |               1 |
# | "1"                      |         565004 |               1 |
# | "1"                      |         565935 |               1 |
# | "1"                      |         568936 |               1 |
# +--------------------------+----------------+-----------------+
#
# +----------------------------------------------------------------------------------------+
# | snp1_vep.transcript_consequences                                                       |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2002... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],23... |
# | [(1,NA,"protein_coding",1,"CCDS30547.1",NA,NA,NA,NA,NA,["downstream_gene_variant"],... |
# | [(1,NA,"protein_coding",1,"CCDS41220.1",NA,NA,NA,NA,NA,["upstream_gene_variant"],47... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4459,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1594,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1450,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],519,N... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],940... |
# +----------------------------------------------------------------------------------------+
#
# +------------------------+-------+-------+---------------+-----------------------+
# | snp1_vep.variant_class | refs  | alts  | alleles       | mnv_vep.assembly_name |
# +------------------------+-------+-------+---------------+-----------------------+
# | str                    | str   | str   | array<str>    | str                   |
# +------------------------+-------+-------+---------------+-----------------------+
# | "SNV"                  | "TGA" | "GGG" | ["TGA","GGG"] | "GRCh37"              |
# | "SNV"                  | "ATA" | "TTC" | ["ATA","TTC"] | "GRCh37"              |
# | "SNV"                  | "TAT" | "GAG" | ["TAT","GAG"] | "GRCh37"              |
# | "SNV"                  | "CTG" | "GTA" | ["CTG","GTA"] | "GRCh37"              |
# | "SNV"                  | "TGG" | "GGC" | ["TGG","GGC"] | "GRCh37"              |
# | "SNV"                  | "CGC" | "TGT" | ["CGC","TGT"] | "GRCh37"              |
# | "SNV"                  | "AGT" | "GGC" | ["AGT","GGC"] | "GRCh37"              |
# | "SNV"                  | "TAT" | "AAC" | ["TAT","AAC"] | "GRCh37"              |
# | "SNV"                  | "CCT" | "TCC" | ["CCT","TCC"] | "GRCh37"              |
# | "SNV"                  | "GTA" | "ATG" | ["GTA","ATG"] | "GRCh37"              |
# +------------------------+-------+-------+---------------+-----------------------+
#
# +-----------------------+-------------------+
# | mnv_vep.allele_string | mnv_vep.ancestral |
# +-----------------------+-------------------+
# | str                   | str               |
# +-----------------------+-------------------+
# | "TGA/GGG"             | NA                |
# | "ATA/TTC"             | NA                |
# | "TAT/GAG"             | NA                |
# | "CTG/GTA"             | NA                |
# | "TGG/GGC"             | NA                |
# | "CGC/TGT"             | NA                |
# | "AGT/GGC"             | NA                |
# | "TAT/AAC"             | NA                |
# | "CCT/TCC"             | NA                |
# | "GTA/ATG"             | NA                |
# +-----------------------+-------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.colocated_variants                                                             |
# +----------------------------------------------------------------------------------------+
# | array<struct{aa_allele: str, aa_maf: float64, afr_allele: str, afr_maf: float64, al... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | [(NA,NA,NA,NA,"TAT/AAC",NA,NA,NA,565006,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,N... |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +-----------------+-------------+--------------------+
# | mnv_vep.context | mnv_vep.end | mnv_vep.id         |
# +-----------------+-------------+--------------------+
# | str             |       int32 | str                |
# +-----------------+-------------+--------------------+
# | NA              |       13118 | "1_13116_TGA/GGG"  |
# | NA              |       51049 | "1_51047_ATA/TTC"  |
# | NA              |       57264 | "1_57262_TAT/GAG"  |
# | NA              |       74792 | "1_74790_CTG/GTA"  |
# | NA              |      362907 | "1_362905_TGG/GGC" |
# | NA              |      559985 | "1_559983_CGC/TGT" |
# | NA              |      564862 | "1_564860_AGT/GGC" |
# | NA              |      565006 | "1_565004_TAT/AAC" |
# | NA              |      565937 | "1_565935_CCT/TCC" |
# | NA              |      568938 | "1_568936_GTA/ATG" |
# +-----------------+-------------+--------------------+
#
# +------------------------------------+
# | mnv_vep.input                      |
# +------------------------------------+
# | str                                |
# +------------------------------------+
# | "1\t13116\t.\tTGA\tGGG\t.\t.\tGT"  |
# | "1\t51047\t.\tATA\tTTC\t.\t.\tGT"  |
# | "1\t57262\t.\tTAT\tGAG\t.\t.\tGT"  |
# | "1\t74790\t.\tCTG\tGTA\t.\t.\tGT"  |
# | "1\t362905\t.\tTGG\tGGC\t.\t.\tGT" |
# | "1\t559983\t.\tCGC\tTGT\t.\t.\tGT" |
# | "1\t564860\t.\tAGT\tGGC\t.\t.\tGT" |
# | "1\t565004\t.\tTAT\tAAC\t.\t.\tGT" |
# | "1\t565935\t.\tCCT\tTCC\t.\t.\tGT" |
# | "1\t568936\t.\tGTA\tATG\t.\t.\tGT" |
# +------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.intergenic_consequences                                                        |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, impact: str, minimis... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +--------------------------------------+
# | mnv_vep.most_severe_consequence      |
# +--------------------------------------+
# | str                                  |
# +--------------------------------------+
# | "intron_variant"                     |
# | "upstream_gene_variant"              |
# | "downstream_gene_variant"            |
# | "downstream_gene_variant"            |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "intron_variant"                     |
# | "non_coding_transcript_exon_variant" |
# | "non_coding_transcript_exon_variant" |
# +--------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.motif_feature_consequences                                                     |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, consequence_terms: array<str>, high_inf_pos: str, i... |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.regulatory_feature_consequences                                                |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, biotype: str, consequence_terms: array<str>, impact... |
# +----------------------------------------------------------------------------------------+
# | [(1,"CTCF_binding_site",["regulatory_region_variant"],"MODIFIER",1,"ENSR00001576075... |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# | NA                                                                                     |
# +----------------------------------------------------------------------------------------+
#
# +-------------------------+---------------+----------------+
# | mnv_vep.seq_region_name | mnv_vep.start | mnv_vep.strand |
# +-------------------------+---------------+----------------+
# | str                     |         int32 |          int32 |
# +-------------------------+---------------+----------------+
# | "1"                     |         13116 |              1 |
# | "1"                     |         51047 |              1 |
# | "1"                     |         57262 |              1 |
# | "1"                     |         74790 |              1 |
# | "1"                     |        362905 |              1 |
# | "1"                     |        559983 |              1 |
# | "1"                     |        564860 |              1 |
# | "1"                     |        565004 |              1 |
# | "1"                     |        565935 |              1 |
# | "1"                     |        568936 |              1 |
# +-------------------------+---------------+----------------+
#
# +----------------------------------------------------------------------------------------+
# | mnv_vep.transcript_consequences                                                        |
# +----------------------------------------------------------------------------------------+
# | array<struct{allele_num: int32, amino_acids: str, biotype: str, canonical: int32, c... |
# +----------------------------------------------------------------------------------------+
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],12... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],2000... |
# | [(1,NA,"unprocessed_pseudogene",NA,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],23... |
# | [(1,NA,"protein_coding",1,"CCDS30547.1",NA,NA,NA,NA,NA,["downstream_gene_variant"],... |
# | [(1,NA,"protein_coding",1,"CCDS41220.1",NA,NA,NA,NA,NA,["upstream_gene_variant"],47... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],4457,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1592,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],1448,... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["upstream_gene_variant"],517,N... |
# | [(1,NA,"unprocessed_pseudogene",1,NA,NA,NA,NA,NA,NA,["downstream_gene_variant"],940... |
# +----------------------------------------------------------------------------------------+
#
# +-----------------------+
# | mnv_vep.variant_class |
# +-----------------------+
# | str                   |
# +-----------------------+
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# | "substitution"        |
# +-----------------------+
# showing top 10 rows

# %% [markdown]
# ## Comparing the effects and categorizing MNV
#
# Now we have individual effect of SNP1, SNP2, as well as combined effect of MNV annotated.
# Next step is to compare those to categorize the MNVs.
#
# Are any "gained" nonsense in our dataset? How many MNVs are actually within a single codon reading frame?
#
# To answer these question, we will first clean the data and get per transcript annotation, focusing on canonical transcripts.
#
# (We will start from those with distance=1. Same logic can be applied to all the processes for distance 2 later.)
#
# (From here on, we are using some home made functions that are helpful for the analysis.
# Although there should be a more efficienc way to import those functions, here for the convenience we will copy and paste in the bottom of this notebook.
# See the "functions" cell for the functions that are used. In practice we need to define those functions first before running this process.)

# %%
#first, select the essential columns (delete some)
vepped_d1_essense = t1.key_by("locus", "refs", "alts") 
vepped_d1_essense = vepped_d1_essense.select("AC", "prev_AC", "prev_AF", "n_hethet", "n_hethom",
                                                     "n_homhom", "snp1_vep", "snp2_vep", "mnv_vep")
# filter to canonicals:
canon_cons_d1 = filter_vep_to_canonical_transcripts(filter_vep_to_canonical_transcripts(
filter_vep_to_canonical_transcripts(vepped_d1_essense, vep_root="snp1_vep"), vep_root="snp2_vep"),
                                                            vep_root="mnv_vep")

###explode by consequence, since there might be more than 1 canonical transcript for a MNV
canon_cons_d1 = canon_cons_d1.annotate(indices=hl.range(0, hl.min(
            hl.len(canon_cons_d1.snp1_vep.transcript_consequences), hl.len(canon_cons_d1.snp2_vep.transcript_consequences))))
canon_cons_d1 = canon_cons_d1.explode('indices')
canon_cons_d1 = canon_cons_d1.transmute(
            snp1_transcript_consequences=canon_cons_d1.snp1_vep.transcript_consequences[canon_cons_d1.indices],
            snp2_transcript_consequences=canon_cons_d1.snp2_vep.transcript_consequences[canon_cons_d1.indices],
            mnv_transcript_consequences=canon_cons_d1.mnv_vep.transcript_consequences[canon_cons_d1.indices],
            )
# keep necessary columns
canon_cons_d1 = canon_cons_d1.select("AC", "prev_AC", "prev_AF", "n_hethet", "n_hethom",
                                             "n_homhom",
                                             "snp1_transcript_consequences",
                                             "snp2_transcript_consequences",
                                             "mnv_transcript_consequences")

# further annotate necessary ones
# codons, consequence_terms, lof, lof_flags, transcript_id
canon_cons_d1 = canon_cons_d1.annotate(
            snp1_cons_term=canon_cons_d1.snp1_transcript_consequences.consequence_terms,
            snp2_cons_term=canon_cons_d1.snp2_transcript_consequences.consequence_terms,
            mnv_cons_term=canon_cons_d1.mnv_transcript_consequences.consequence_terms,
            snp1_codons=canon_cons_d1.snp1_transcript_consequences.codons,
            snp2_codons=canon_cons_d1.snp2_transcript_consequences.codons,
            mnv_codons=canon_cons_d1.mnv_transcript_consequences.codons,
            snp1_amino_acids=canon_cons_d1.snp1_transcript_consequences.amino_acids,
            snp2_amino_acids=canon_cons_d1.snp2_transcript_consequences.amino_acids,
            mnv_amino_acids=canon_cons_d1.mnv_transcript_consequences.amino_acids,
            snp1_lof=canon_cons_d1.snp1_transcript_consequences.lof,
            snp2_lof=canon_cons_d1.snp2_transcript_consequences.lof,
            mnv_lof=canon_cons_d1.mnv_transcript_consequences.lof,
            transcript_id=canon_cons_d1.snp1_transcript_consequences.transcript_id
            )

# filter to those that the codon are changed within a single reading frame
canon_cons_d1 = canon_cons_d1.filter(
            (canon_cons_d1.snp1_codons.length() == 7) & (canon_cons_d1.snp2_codons.length() == 7) & (
            canon_cons_d1.mnv_codons.length() == 7))

# %% [markdown]
# In above we have filtered to select MNVs only falling on canonical transcripts, within a single codon reading frame.

# %%
canon_cons_d1.show()
# Out:
# 2019-03-10 01:47:58 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:48:03 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:48:08 Hail: INFO: Coerced sorted dataset
# +---------------+------+------+-------+---------+----------+----------+----------+
# | locus         | refs | alts |    AC | prev_AC |  prev_AF | n_hethet | n_hethom |
# +---------------+------+------+-------+---------+----------+----------+----------+
# | locus<GRCh37> | str  | str  | int32 |   int32 |  float64 |    int64 |    int64 |
# +---------------+------+------+-------+---------+----------+----------+----------+
# | 1:901922      | "GC" | "AA" |    53 |      53 | 1.06e-02 |       51 |        1 |
# | 1:909238      | "GT" | "CC" |     1 |    3889 | 7.77e-01 |        0 |        0 |
# +---------------+------+------+-------+---------+----------+----------+----------+
#
# +----------+-----------------------------------------+
# | n_homhom | snp1_transcript_consequences.allele_num |
# +----------+-----------------------------------------+
# |    int64 |                                   int32 |
# +----------+-----------------------------------------+
# |        0 |                                       1 |
# |        1 |                                       1 |
# +----------+-----------------------------------------+
#
# +------------------------------------------+--------------------------------------+
# | snp1_transcript_consequences.amino_acids | snp1_transcript_consequences.biotype |
# +------------------------------------------+--------------------------------------+
# | str                                      | str                                  |
# +------------------------------------------+--------------------------------------+
# | "S/N"                                    | "protein_coding"                     |
# | "R/P"                                    | "protein_coding"                     |
# +------------------------------------------+--------------------------------------+
#
# +----------------------------------------+-----------------------------------+
# | snp1_transcript_consequences.canonical | snp1_transcript_consequences.ccds |
# +----------------------------------------+-----------------------------------+
# |                                  int32 | str                               |
# +----------------------------------------+-----------------------------------+
# |                                      1 | "CCDS4.1"                         |
# |                                      1 | "CCDS4.1"                         |
# +----------------------------------------+-----------------------------------+
#
# +-----------------------------------------+---------------------------------------+
# | snp1_transcript_consequences.cdna_start | snp1_transcript_consequences.cdna_end |
# +-----------------------------------------+---------------------------------------+
# |                                   int32 |                                 int32 |
# +-----------------------------------------+---------------------------------------+
# |                                      46 |                                    46 |
# |                                    1495 |                                  1495 |
# +-----------------------------------------+---------------------------------------+
#
# +--------------------------------------+----------------------------------------+
# | snp1_transcript_consequences.cds_end | snp1_transcript_consequences.cds_start |
# +--------------------------------------+----------------------------------------+
# |                                int32 |                                  int32 |
# +--------------------------------------+----------------------------------------+
# |                                   11 |                                     11 |
# |                                 1460 |                                   1460 |
# +--------------------------------------+----------------------------------------+
#
# +-------------------------------------+------------------------------------------------+
# | snp1_transcript_consequences.codons | snp1_transcript_consequences.consequence_terms |
# +-------------------------------------+------------------------------------------------+
# | str                                 | array<str>                                     |
# +-------------------------------------+------------------------------------------------+
# | "aGc/aAc"                           | ["missense_variant"]                           |
# | "cGt/cCt"                           | ["missense_variant"]                           |
# +-------------------------------------+------------------------------------------------+
#
# +---------------------------------------+
# | snp1_transcript_consequences.distance |
# +---------------------------------------+
# |                                 int32 |
# +---------------------------------------+
# |                                    NA |
# |                                    NA |
# +---------------------------------------+
#
# +---------------------------------------------------------+
# | snp1_transcript_consequences.domains                    |
# +---------------------------------------------------------+
# | array<struct{db: str, name: str}>                       |
# +---------------------------------------------------------+
# | NA                                                      |
# | [("hmmpanther","PTHR22826"),("hmmpanther","PTHR22826")] |
# +---------------------------------------------------------+
#
# +-----------------------------------+--------------------------------------+
# | snp1_transcript_consequences.exon | snp1_transcript_consequences.gene_id |
# +-----------------------------------+--------------------------------------+
# | str                               | str                                  |
# +-----------------------------------+--------------------------------------+
# | "1/16"                            | "ENSG00000187583"                    |
# | "14/16"                           | "ENSG00000187583"                    |
# +-----------------------------------+--------------------------------------+
#
# +-----------------------------------------+------------------------------------------+
# | snp1_transcript_consequences.gene_pheno | snp1_transcript_consequences.gene_symbol |
# +-----------------------------------------+------------------------------------------+
# |                                   int32 | str                                      |
# +-----------------------------------------+------------------------------------------+
# |                                      NA | "PLEKHN1"                                |
# |                                      NA | "PLEKHN1"                                |
# +-----------------------------------------+------------------------------------------+
#
# +-------------------------------------------------+--------------------------------------+
# | snp1_transcript_consequences.gene_symbol_source | snp1_transcript_consequences.hgnc_id |
# +-------------------------------------------------+--------------------------------------+
# | str                                             | str                                  |
# +-------------------------------------------------+--------------------------------------+
# | "HGNC"                                          | "25284"                              |
# | "HGNC"                                          | "25284"                              |
# +-------------------------------------------------+--------------------------------------+
#
# +------------------------------------+------------------------------------+
# | snp1_transcript_consequences.hgvsc | snp1_transcript_consequences.hgvsp |
# +------------------------------------+------------------------------------+
# | str                                | str                                |
# +------------------------------------+------------------------------------+
# | "ENST00000379410.3:c.11G>A"        | "ENSP00000368720.3:p.Ser4Asn"      |
# | "ENST00000379410.3:c.1460G>C"      | "ENSP00000368720.3:p.Arg487Pro"    |
# +------------------------------------+------------------------------------+
#
# +------------------------------------------+-------------------------------------+
# | snp1_transcript_consequences.hgvs_offset | snp1_transcript_consequences.impact |
# +------------------------------------------+-------------------------------------+
# |                                    int32 | str                                 |
# +------------------------------------------+-------------------------------------+
# |                                       NA | "MODERATE"                          |
# |                                       NA | "MODERATE"                          |
# +------------------------------------------+-------------------------------------+
#
# +-------------------------------------+----------------------------------+
# | snp1_transcript_consequences.intron | snp1_transcript_consequences.lof |
# +-------------------------------------+----------------------------------+
# | str                                 | str                              |
# +-------------------------------------+----------------------------------+
# | NA                                  | NA                               |
# | NA                                  | NA                               |
# +-------------------------------------+----------------------------------+
#
# +----------------------------------------+-----------------------------------------+
# | snp1_transcript_consequences.lof_flags | snp1_transcript_consequences.lof_filter |
# +----------------------------------------+-----------------------------------------+
# | str                                    | str                                     |
# +----------------------------------------+-----------------------------------------+
# | NA                                     | NA                                      |
# | NA                                     | NA                                      |
# +----------------------------------------+-----------------------------------------+
#
# +---------------------------------------+----------------------------------------+
# | snp1_transcript_consequences.lof_info | snp1_transcript_consequences.minimised |
# +---------------------------------------+----------------------------------------+
# | str                                   |                                  int32 |
# +---------------------------------------+----------------------------------------+
# | NA                                    |                                      1 |
# | NA                                    |                                      1 |
# +---------------------------------------+----------------------------------------+
#
# +--------------------------------------------------+
# | snp1_transcript_consequences.polyphen_prediction |
# +--------------------------------------------------+
# | str                                              |
# +--------------------------------------------------+
# | "benign"                                         |
# | "benign"                                         |
# +--------------------------------------------------+
#
# +---------------------------------------------+------------------------------------------+
# | snp1_transcript_consequences.polyphen_score | snp1_transcript_consequences.protein_end |
# +---------------------------------------------+------------------------------------------+
# |                                     float64 |                                    int32 |
# +---------------------------------------------+------------------------------------------+
# |                                    1.32e-01 |                                        4 |
# |                                    0.00e+00 |                                      487 |
# +---------------------------------------------+------------------------------------------+
#
# +--------------------------------------------+-----------------------------------------+
# | snp1_transcript_consequences.protein_start | snp1_transcript_consequences.protein_id |
# +--------------------------------------------+-----------------------------------------+
# |                                      int32 | str                                     |
# +--------------------------------------------+-----------------------------------------+
# |                                          4 | "ENSP00000368720"                       |
# |                                        487 | "ENSP00000368720"                       |
# +--------------------------------------------+-----------------------------------------+
#
# +----------------------------------------------+-----------------------------------------+
# | snp1_transcript_consequences.sift_prediction | snp1_transcript_consequences.sift_score |
# +----------------------------------------------+-----------------------------------------+
# | str                                          |                                 float64 |
# +----------------------------------------------+-----------------------------------------+
# | "tolerated"                                  |                                6.00e-02 |
# | "tolerated"                                  |                                3.10e-01 |
# +----------------------------------------------+-----------------------------------------+
#
# +-------------------------------------+----------------------------------------+
# | snp1_transcript_consequences.strand | snp1_transcript_consequences.swissprot |
# +-------------------------------------+----------------------------------------+
# |                               int32 | str                                    |
# +-------------------------------------+----------------------------------------+
# |                                   1 | "Q494U1"                               |
# |                                   1 | "Q494U1"                               |
# +-------------------------------------+----------------------------------------+
#
# +--------------------------------------------+-------------------------------------+
# | snp1_transcript_consequences.transcript_id | snp1_transcript_consequences.trembl |
# +--------------------------------------------+-------------------------------------+
# | str                                        | str                                 |
# +--------------------------------------------+-------------------------------------+
# | "ENST00000379410"                          | "J3KSM5"                            |
# | "ENST00000379410"                          | "J3KSM5"                            |
# +--------------------------------------------+-------------------------------------+
#
# +--------------------------------------+---------------------------------------------+
# | snp1_transcript_consequences.uniparc | snp1_transcript_consequences.variant_allele |
# +--------------------------------------+---------------------------------------------+
# | str                                  | str                                         |
# +--------------------------------------+---------------------------------------------+
# | "UPI00001416D8"                      | "A"                                         |
# | "UPI00001416D8"                      | "C"                                         |
# +--------------------------------------+---------------------------------------------+
#
# +-----------------------------------------+------------------------------------------+
# | snp2_transcript_consequences.allele_num | snp2_transcript_consequences.amino_acids |
# +-----------------------------------------+------------------------------------------+
# |                                   int32 | str                                      |
# +-----------------------------------------+------------------------------------------+
# |                                       1 | "S/R"                                    |
# |                                       1 | "R"                                      |
# +-----------------------------------------+------------------------------------------+
#
# +--------------------------------------+----------------------------------------+
# | snp2_transcript_consequences.biotype | snp2_transcript_consequences.canonical |
# +--------------------------------------+----------------------------------------+
# | str                                  |                                  int32 |
# +--------------------------------------+----------------------------------------+
# | "protein_coding"                     |                                      1 |
# | "protein_coding"                     |                                      1 |
# +--------------------------------------+----------------------------------------+
#
# +-----------------------------------+-----------------------------------------+
# | snp2_transcript_consequences.ccds | snp2_transcript_consequences.cdna_start |
# +-----------------------------------+-----------------------------------------+
# | str                               |                                   int32 |
# +-----------------------------------+-----------------------------------------+
# | "CCDS4.1"                         |                                      47 |
# | "CCDS4.1"                         |                                    1496 |
# +-----------------------------------+-----------------------------------------+
#
# +---------------------------------------+--------------------------------------+
# | snp2_transcript_consequences.cdna_end | snp2_transcript_consequences.cds_end |
# +---------------------------------------+--------------------------------------+
# |                                 int32 |                                int32 |
# +---------------------------------------+--------------------------------------+
# |                                    47 |                                   12 |
# |                                  1496 |                                 1461 |
# +---------------------------------------+--------------------------------------+
#
# +----------------------------------------+-------------------------------------+
# | snp2_transcript_consequences.cds_start | snp2_transcript_consequences.codons |
# +----------------------------------------+-------------------------------------+
# |                                  int32 | str                                 |
# +----------------------------------------+-------------------------------------+
# |                                     12 | "agC/agA"                           |
# |                                   1461 | "cgT/cgC"                           |
# +----------------------------------------+-------------------------------------+
#
# +------------------------------------------------+---------------------------------------+
# | snp2_transcript_consequences.consequence_terms | snp2_transcript_consequences.distance |
# +------------------------------------------------+---------------------------------------+
# | array<str>                                     |                                 int32 |
# +------------------------------------------------+---------------------------------------+
# | ["missense_variant"]                           |                                    NA |
# | ["synonymous_variant"]                         |                                    NA |
# +------------------------------------------------+---------------------------------------+
#
# +---------------------------------------------------------+
# | snp2_transcript_consequences.domains                    |
# +---------------------------------------------------------+
# | array<struct{db: str, name: str}>                       |
# +---------------------------------------------------------+
# | NA                                                      |
# | [("hmmpanther","PTHR22826"),("hmmpanther","PTHR22826")] |
# +---------------------------------------------------------+
#
# +-----------------------------------+--------------------------------------+
# | snp2_transcript_consequences.exon | snp2_transcript_consequences.gene_id |
# +-----------------------------------+--------------------------------------+
# | str                               | str                                  |
# +-----------------------------------+--------------------------------------+
# | "1/16"                            | "ENSG00000187583"                    |
# | "14/16"                           | "ENSG00000187583"                    |
# +-----------------------------------+--------------------------------------+
#
# +-----------------------------------------+------------------------------------------+
# | snp2_transcript_consequences.gene_pheno | snp2_transcript_consequences.gene_symbol |
# +-----------------------------------------+------------------------------------------+
# |                                   int32 | str                                      |
# +-----------------------------------------+------------------------------------------+
# |                                      NA | "PLEKHN1"                                |
# |                                      NA | "PLEKHN1"                                |
# +-----------------------------------------+------------------------------------------+
#
# +-------------------------------------------------+--------------------------------------+
# | snp2_transcript_consequences.gene_symbol_source | snp2_transcript_consequences.hgnc_id |
# +-------------------------------------------------+--------------------------------------+
# | str                                             | str                                  |
# +-------------------------------------------------+--------------------------------------+
# | "HGNC"                                          | "25284"                              |
# | "HGNC"                                          | "25284"                              |
# +-------------------------------------------------+--------------------------------------+
#
# +------------------------------------+------------------------------------+
# | snp2_transcript_consequences.hgvsc | snp2_transcript_consequences.hgvsp |
# +------------------------------------+------------------------------------+
# | str                                | str                                |
# +------------------------------------+------------------------------------+
# | "ENST00000379410.3:c.12C>A"        | "ENSP00000368720.3:p.Ser4Arg"      |
# | "ENST00000379410.3:c.1461T>C"      | "ENST00000379410.3:c.1461T>C(p.=)" |
# +------------------------------------+------------------------------------+
#
# +------------------------------------------+-------------------------------------+
# | snp2_transcript_consequences.hgvs_offset | snp2_transcript_consequences.impact |
# +------------------------------------------+-------------------------------------+
# |                                    int32 | str                                 |
# +------------------------------------------+-------------------------------------+
# |                                       NA | "MODERATE"                          |
# |                                       NA | "LOW"                               |
# +------------------------------------------+-------------------------------------+
#
# +-------------------------------------+----------------------------------+
# | snp2_transcript_consequences.intron | snp2_transcript_consequences.lof |
# +-------------------------------------+----------------------------------+
# | str                                 | str                              |
# +-------------------------------------+----------------------------------+
# | NA                                  | NA                               |
# | NA                                  | NA                               |
# +-------------------------------------+----------------------------------+
#
# +----------------------------------------+-----------------------------------------+
# | snp2_transcript_consequences.lof_flags | snp2_transcript_consequences.lof_filter |
# +----------------------------------------+-----------------------------------------+
# | str                                    | str                                     |
# +----------------------------------------+-----------------------------------------+
# | NA                                     | NA                                      |
# | NA                                     | NA                                      |
# +----------------------------------------+-----------------------------------------+
#
# +----------------------------------------------------------------------------------------+
# | snp2_transcript_consequences.lof_info                                                  |
# +----------------------------------------------------------------------------------------+
# | str                                                                                    |
# +----------------------------------------------------------------------------------------+
# | NA                                                                                     |
# | "EXON_END:909431,DE_NOVO_DONOR_MES:-5.07903292316591,DE_NOVO_DONOR_MES_POS:-198,DE_... |
# +----------------------------------------------------------------------------------------+
#
# +----------------------------------------+
# | snp2_transcript_consequences.minimised |
# +----------------------------------------+
# |                                  int32 |
# +----------------------------------------+
# |                                      1 |
# |                                      1 |
# +----------------------------------------+
#
# +--------------------------------------------------+
# | snp2_transcript_consequences.polyphen_prediction |
# +--------------------------------------------------+
# | str                                              |
# +--------------------------------------------------+
# | "possibly_damaging"                              |
# | NA                                               |
# +--------------------------------------------------+
#
# +---------------------------------------------+------------------------------------------+
# | snp2_transcript_consequences.polyphen_score | snp2_transcript_consequences.protein_end |
# +---------------------------------------------+------------------------------------------+
# |                                     float64 |                                    int32 |
# +---------------------------------------------+------------------------------------------+
# |                                    8.94e-01 |                                        4 |
# |                                          NA |                                      487 |
# +---------------------------------------------+------------------------------------------+
#
# +--------------------------------------------+-----------------------------------------+
# | snp2_transcript_consequences.protein_start | snp2_transcript_consequences.protein_id |
# +--------------------------------------------+-----------------------------------------+
# |                                      int32 | str                                     |
# +--------------------------------------------+-----------------------------------------+
# |                                          4 | "ENSP00000368720"                       |
# |                                        487 | "ENSP00000368720"                       |
# +--------------------------------------------+-----------------------------------------+
#
# +----------------------------------------------+-----------------------------------------+
# | snp2_transcript_consequences.sift_prediction | snp2_transcript_consequences.sift_score |
# +----------------------------------------------+-----------------------------------------+
# | str                                          |                                 float64 |
# +----------------------------------------------+-----------------------------------------+
# | "deleterious"                                |                                3.00e-02 |
# | NA                                           |                                      NA |
# +----------------------------------------------+-----------------------------------------+
#
# +-------------------------------------+----------------------------------------+
# | snp2_transcript_consequences.strand | snp2_transcript_consequences.swissprot |
# +-------------------------------------+----------------------------------------+
# |                               int32 | str                                    |
# +-------------------------------------+----------------------------------------+
# |                                   1 | "Q494U1"                               |
# |                                   1 | "Q494U1"                               |
# +-------------------------------------+----------------------------------------+
#
# +--------------------------------------------+-------------------------------------+
# | snp2_transcript_consequences.transcript_id | snp2_transcript_consequences.trembl |
# +--------------------------------------------+-------------------------------------+
# | str                                        | str                                 |
# +--------------------------------------------+-------------------------------------+
# | "ENST00000379410"                          | "J3KSM5"                            |
# | "ENST00000379410"                          | "J3KSM5"                            |
# +--------------------------------------------+-------------------------------------+
#
# +--------------------------------------+---------------------------------------------+
# | snp2_transcript_consequences.uniparc | snp2_transcript_consequences.variant_allele |
# +--------------------------------------+---------------------------------------------+
# | str                                  | str                                         |
# +--------------------------------------+---------------------------------------------+
# | "UPI00001416D8"                      | "A"                                         |
# | "UPI00001416D8"                      | "C"                                         |
# +--------------------------------------+---------------------------------------------+
#
# +----------------------------------------+-----------------------------------------+
# | mnv_transcript_consequences.allele_num | mnv_transcript_consequences.amino_acids |
# +----------------------------------------+-----------------------------------------+
# |                                  int32 | str                                     |
# +----------------------------------------+-----------------------------------------+
# |                                      1 | "S/K"                                   |
# |                                      1 | "R/P"                                   |
# +----------------------------------------+-----------------------------------------+
#
# +-------------------------------------+---------------------------------------+
# | mnv_transcript_consequences.biotype | mnv_transcript_consequences.canonical |
# +-------------------------------------+---------------------------------------+
# | str                                 |                                 int32 |
# +-------------------------------------+---------------------------------------+
# | "protein_coding"                    |                                     1 |
# | "protein_coding"                    |                                     1 |
# +-------------------------------------+---------------------------------------+
#
# +----------------------------------+----------------------------------------+
# | mnv_transcript_consequences.ccds | mnv_transcript_consequences.cdna_start |
# +----------------------------------+----------------------------------------+
# | str                              |                                  int32 |
# +----------------------------------+----------------------------------------+
# | "CCDS4.1"                        |                                     46 |
# | "CCDS4.1"                        |                                   1495 |
# +----------------------------------+----------------------------------------+
#
# +--------------------------------------+-------------------------------------+
# | mnv_transcript_consequences.cdna_end | mnv_transcript_consequences.cds_end |
# +--------------------------------------+-------------------------------------+
# |                                int32 |                               int32 |
# +--------------------------------------+-------------------------------------+
# |                                   47 |                                  12 |
# |                                 1496 |                                1461 |
# +--------------------------------------+-------------------------------------+
#
# +---------------------------------------+------------------------------------+
# | mnv_transcript_consequences.cds_start | mnv_transcript_consequences.codons |
# +---------------------------------------+------------------------------------+
# |                                 int32 | str                                |
# +---------------------------------------+------------------------------------+
# |                                    11 | "aGC/aAA"                          |
# |                                  1460 | "cGT/cCC"                          |
# +---------------------------------------+------------------------------------+
#
# +-----------------------------------------------+--------------------------------------+
# | mnv_transcript_consequences.consequence_terms | mnv_transcript_consequences.distance |
# +-----------------------------------------------+--------------------------------------+
# | array<str>                                    |                                int32 |
# +-----------------------------------------------+--------------------------------------+
# | ["missense_variant"]                          |                                   NA |
# | ["missense_variant"]                          |                                   NA |
# +-----------------------------------------------+--------------------------------------+
#
# +---------------------------------------------------------+
# | mnv_transcript_consequences.domains                     |
# +---------------------------------------------------------+
# | array<struct{db: str, name: str}>                       |
# +---------------------------------------------------------+
# | NA                                                      |
# | [("hmmpanther","PTHR22826"),("hmmpanther","PTHR22826")] |
# +---------------------------------------------------------+
#
# +----------------------------------+-------------------------------------+
# | mnv_transcript_consequences.exon | mnv_transcript_consequences.gene_id |
# +----------------------------------+-------------------------------------+
# | str                              | str                                 |
# +----------------------------------+-------------------------------------+
# | "1/16"                           | "ENSG00000187583"                   |
# | "14/16"                          | "ENSG00000187583"                   |
# +----------------------------------+-------------------------------------+
#
# +----------------------------------------+-----------------------------------------+
# | mnv_transcript_consequences.gene_pheno | mnv_transcript_consequences.gene_symbol |
# +----------------------------------------+-----------------------------------------+
# |                                  int32 | str                                     |
# +----------------------------------------+-----------------------------------------+
# |                                     NA | "PLEKHN1"                               |
# |                                     NA | "PLEKHN1"                               |
# +----------------------------------------+-----------------------------------------+
#
# +------------------------------------------------+-------------------------------------+
# | mnv_transcript_consequences.gene_symbol_source | mnv_transcript_consequences.hgnc_id |
# +------------------------------------------------+-------------------------------------+
# | str                                            | str                                 |
# +------------------------------------------------+-------------------------------------+
# | "HGNC"                                         | "25284"                             |
# | "HGNC"                                         | "25284"                             |
# +------------------------------------------------+-------------------------------------+
#
# +-------------------------------------------+-----------------------------------+
# | mnv_transcript_consequences.hgvsc         | mnv_transcript_consequences.hgvsp |
# +-------------------------------------------+-----------------------------------+
# | str                                       | str                               |
# +-------------------------------------------+-----------------------------------+
# | "ENST00000379410.3:c.11_12delGCinsAA"     | "ENSP00000368720.3:p.Ser4Lys"     |
# | "ENST00000379410.3:c.1460_1461delGTinsCC" | "ENSP00000368720.3:p.Arg487Pro"   |
# +-------------------------------------------+-----------------------------------+
#
# +-----------------------------------------+------------------------------------+
# | mnv_transcript_consequences.hgvs_offset | mnv_transcript_consequences.impact |
# +-----------------------------------------+------------------------------------+
# |                                   int32 | str                                |
# +-----------------------------------------+------------------------------------+
# |                                      NA | "MODERATE"                         |
# |                                      NA | "MODERATE"                         |
# +-----------------------------------------+------------------------------------+
#
# +------------------------------------+---------------------------------+
# | mnv_transcript_consequences.intron | mnv_transcript_consequences.lof |
# +------------------------------------+---------------------------------+
# | str                                | str                             |
# +------------------------------------+---------------------------------+
# | NA                                 | NA                              |
# | NA                                 | NA                              |
# +------------------------------------+---------------------------------+
#
# +---------------------------------------+----------------------------------------+
# | mnv_transcript_consequences.lof_flags | mnv_transcript_consequences.lof_filter |
# +---------------------------------------+----------------------------------------+
# | str                                   | str                                    |
# +---------------------------------------+----------------------------------------+
# | NA                                    | NA                                     |
# | NA                                    | NA                                     |
# +---------------------------------------+----------------------------------------+
#
# +--------------------------------------+---------------------------------------+
# | mnv_transcript_consequences.lof_info | mnv_transcript_consequences.minimised |
# +--------------------------------------+---------------------------------------+
# | str                                  |                                 int32 |
# +--------------------------------------+---------------------------------------+
# | NA                                   |                                     1 |
# | NA                                   |                                     1 |
# +--------------------------------------+---------------------------------------+
#
# +-------------------------------------------------+
# | mnv_transcript_consequences.polyphen_prediction |
# +-------------------------------------------------+
# | str                                             |
# +-------------------------------------------------+
# | "possibly_damaging"                             |
# | "benign"                                        |
# +-------------------------------------------------+
#
# +--------------------------------------------+-----------------------------------------+
# | mnv_transcript_consequences.polyphen_score | mnv_transcript_consequences.protein_end |
# +--------------------------------------------+-----------------------------------------+
# |                                    float64 |                                   int32 |
# +--------------------------------------------+-----------------------------------------+
# |                                   7.51e-01 |                                       4 |
# |                                   0.00e+00 |                                     487 |
# +--------------------------------------------+-----------------------------------------+
#
# +-------------------------------------------+----------------------------------------+
# | mnv_transcript_consequences.protein_start | mnv_transcript_consequences.protein_id |
# +-------------------------------------------+----------------------------------------+
# |                                     int32 | str                                    |
# +-------------------------------------------+----------------------------------------+
# |                                         4 | "ENSP00000368720"                      |
# |                                       487 | "ENSP00000368720"                      |
# +-------------------------------------------+----------------------------------------+
#
# +---------------------------------------------+----------------------------------------+
# | mnv_transcript_consequences.sift_prediction | mnv_transcript_consequences.sift_score |
# +---------------------------------------------+----------------------------------------+
# | str                                         |                                float64 |
# +---------------------------------------------+----------------------------------------+
# | "deleterious"                               |                               5.00e-02 |
# | "tolerated"                                 |                               3.10e-01 |
# +---------------------------------------------+----------------------------------------+
#
# +------------------------------------+---------------------------------------+
# | mnv_transcript_consequences.strand | mnv_transcript_consequences.swissprot |
# +------------------------------------+---------------------------------------+
# |                              int32 | str                                   |
# +------------------------------------+---------------------------------------+
# |                                  1 | "Q494U1"                              |
# |                                  1 | "Q494U1"                              |
# +------------------------------------+---------------------------------------+
#
# +-------------------------------------------+------------------------------------+
# | mnv_transcript_consequences.transcript_id | mnv_transcript_consequences.trembl |
# +-------------------------------------------+------------------------------------+
# | str                                       | str                                |
# +-------------------------------------------+------------------------------------+
# | "ENST00000379410"                         | "J3KSM5"                           |
# | "ENST00000379410"                         | "J3KSM5"                           |
# +-------------------------------------------+------------------------------------+
#
# +-------------------------------------+--------------------------------------------+
# | mnv_transcript_consequences.uniparc | mnv_transcript_consequences.variant_allele |
# +-------------------------------------+--------------------------------------------+
# | str                                 | str                                        |
# +-------------------------------------+--------------------------------------------+
# | "UPI00001416D8"                     | "AA"                                       |
# | "UPI00001416D8"                     | "CC"                                       |
# +-------------------------------------+--------------------------------------------+
#
# +----------------------+------------------------+----------------------+-------------+
# | snp1_cons_term       | snp2_cons_term         | mnv_cons_term        | snp1_codons |
# +----------------------+------------------------+----------------------+-------------+
# | array<str>           | array<str>             | array<str>           | str         |
# +----------------------+------------------------+----------------------+-------------+
# | ["missense_variant"] | ["missense_variant"]   | ["missense_variant"] | "aGc/aAc"   |
# | ["missense_variant"] | ["synonymous_variant"] | ["missense_variant"] | "cGt/cCt"   |
# +----------------------+------------------------+----------------------+-------------+
#
# +-------------+------------+------------------+------------------+-----------------+
# | snp2_codons | mnv_codons | snp1_amino_acids | snp2_amino_acids | mnv_amino_acids |
# +-------------+------------+------------------+------------------+-----------------+
# | str         | str        | str              | str              | str             |
# +-------------+------------+------------------+------------------+-----------------+
# | "agC/agA"   | "aGC/aAA"  | "S/N"            | "S/R"            | "S/K"           |
# | "cgT/cgC"   | "cGT/cCC"  | "R/P"            | "R"              | "R/P"           |
# +-------------+------------+------------------+------------------+-----------------+
#
# +----------+----------+---------+-------------------+
# | snp1_lof | snp2_lof | mnv_lof | transcript_id     |
# +----------+----------+---------+-------------------+
# | str      | str      | str     | str               |
# +----------+----------+---------+-------------------+
# | NA       | NA       | NA      | "ENST00000379410" |
# | NA       | NA       | NA      | "ENST00000379410" |
# +----------+----------+---------+-------------------+

# %% [markdown]
# For the last step, we will actually use traditional dataframe approach, by turning the table to pandas dataframe.
# (the flexibility of `apply` command pandas has is still attractive!)
#
# Then we can annotate the most severe consequence out of all the possible consequences,
# and also categorize the MNV by comparing the consequence of SNP1, SNP2, and MNV.

# %%
#keep the necessary columns and turn to pandas dataframe
canon_cons_pd1 = canon_cons_d1.select("snp1_cons_term", "snp2_cons_term", "mnv_cons_term", "snp1_codons",
                                              "snp2_codons", "mnv_codons", "snp1_amino_acids", "snp2_amino_acids",
                                              "mnv_amino_acids", "snp1_lof", "snp2_lof", "mnv_lof", "transcript_id",
                                              "AC", "prev_AC", "n_hethet", "n_hethom", "n_homhom").to_pandas()
# get the most severe consequence
canon_cons_pd1["snp1_sev"] = canon_cons_pd1.snp1_cons_term.apply(lambda x: cons_term_most_severe(x))
canon_cons_pd1["snp2_sev"] = canon_cons_pd1.snp2_cons_term.apply(lambda x: cons_term_most_severe(x))
canon_cons_pd1["mnv_sev"] = canon_cons_pd1.mnv_cons_term.apply(lambda x: cons_term_most_severe(x))
# annotate the category
canon_cons_pd1["categ"] = canon_cons_pd1.apply(
            lambda x: mnv_category(x["snp1_sev"], x["snp2_sev"], x["mnv_sev"], x["snp1_amino_acids"],
                                   x["snp2_amino_acids"],
                                   x["mnv_amino_acids"]), axis=1)
#rewrite lof flags just in case if lof column is all None (NA) and that causes error
canon_cons_pd1.snp1_lof = canon_cons_pd1.snp1_lof.astype(str)
canon_cons_pd1.snp2_lof = canon_cons_pd1.snp2_lof.astype(str)
canon_cons_pd1.mnv_lof = canon_cons_pd1.mnv_lof.astype(str)
# Out:
# 2019-03-10 01:50:09 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:50:09 Hail: INFO: Coerced sorted dataset
# 2019-03-10 01:50:10 Hail: INFO: Coerced sorted dataset

# %%
display(canon_cons_pd1)
# Out:
#   locus.contig  locus.position refs alts      snp1_cons_term  \
# 0            1          901922   GC   AA  [missense_variant]
# 1            1          909238   GT   CC  [missense_variant]
#
#          snp2_cons_term       mnv_cons_term snp1_codons snp2_codons  \
# 0    [missense_variant]  [missense_variant]     aGc/aAc     agC/agA
# 1  [synonymous_variant]  [missense_variant]     cGt/cCt     cgT/cgC
#
#   mnv_codons  ...    transcript_id  AC prev_AC n_hethet n_hethom n_homhom  \
# 0    aGC/aAA  ...  ENST00000379410  53      53       51        1        0
# 1    cGT/cCC  ...  ENST00000379410   1    3889        0        0        1
#
#            snp1_sev            snp2_sev           mnv_sev             categ
# 0  missense_variant    missense_variant  missense_variant  Changed missense
# 1  missense_variant  synonymous_variant  missense_variant         Unchanged
#
# [2 rows x 26 columns]

# %% [markdown]
# ## End notes
#
# - After all, it turns out that there are only 2 MNVs of distance 1 that falls within a codon reading frame. One of them is "Changed missense", and the other is "Unchanged".
#
# (Not surprising considering that we were just playing around with a small chunk of region -- again the very useful case of cloud computation is when dealing with larger dataset.)
#
# - We can do pretty much the same thing in MNVs of distance 2 (just replace the `vepped_d1_essense = t1.key_by("locus", "refs", "alts") ` with
# `vepped_d2_essense = t2.key_by("locus", "refs", "alts") ` and all the downstream `d1` to `d2` for clarification.).
#
# - (also note that running vep after annotating the sequence context sometimes raise, because of memory issue. In such case we recommend to increase the number of clusters.)
#
# - Again we do provide a function `annotate_vep_mnv` that does all the processes above in a single line. Note that we need to specify the distance of the MNV for this function (i.e. you will run this function 2 times, one for distance 1, and another for distance 2)
#
# - In the next section `functional_impact.ipynb`, we will use the real summary data from `gnomAD` exome -- a collection of 31,510 MNVs falling within a single codon!

# %% [markdown]
# ## Functions
# Below are the list of functions we defined in this notebook (before running all the processes above).

# %%
def filter_vep_to_canonical_transcripts(mt: Union[hl.MatrixTable, hl.Table],
                                        vep_root: str = 'vep') -> Union[hl.MatrixTable, hl.Table]:
    canonical = mt[vep_root].transcript_consequences.filter(lambda csq: csq.canonical == 1)
    vep_data = mt[vep_root].annotate(transcript_consequences=canonical)
    return mt.annotate_rows(**{vep_root: vep_data}) if isinstance(mt, hl.MatrixTable) else mt.annotate(**{vep_root: vep_data})

def mnv_category_by_aa_change(snp1_con, snp2_con, mnv_con,aa1,aa2,aa3):
    if (snp1_con, snp2_con, mnv_con)==("synonymous_variant","missense_variant","missense_variant"):
        if aa2==aa3: return ("Unchanged")
        else: return ("Changed missense")
    elif (snp1_con, snp2_con, mnv_con)==("missense_variant","synonymous_variant","missense_variant"):
        if aa1==aa3: return ("Unchanged")
        else: return ("Changed missense")
    elif (snp1_con, snp2_con, mnv_con)==("missense_variant","missense_variant","missense_variant"):
        if ((aa1==aa3) or (aa2==aa3)):
            return ("Partially changed missense")
        else: return ("Changed missense")
    else: return ("something wrong going on")

def cons_term_most_severe(cons_term_array):
    if "start_lost" in cons_term_array: return ("start_lost") #by definition this is sufficient to determine the mnv is uninteresting
    elif "stop_lost" in cons_term_array: return ("stop_lost")
    elif "stop_gained" in cons_term_array: return ("stop_gained")
    elif "missense_variant" in cons_term_array: return ("missense_variant")
    elif "stop_retained_variant" in cons_term_array: return ("stop_retained_variant")
    elif "synonymous_variant" in cons_term_array: return ("synonymous_variant")
    else: return ("Noncoding_or_else")

def mnv_category(snp1_con, snp2_con, mnv_con, aa1, aa2, aa3):
    # return the MNV consequence category, such as gained PTV, unchange, etc.
    # just classify everything of 3*3*3=27 pattern.
    #plus, case where we see start_lost / stop_lost
    # and if undeterminisitic, look at the aa change and determine.
    if snp1_con == "synonymous_variant":
        if snp2_con == "synonymous_variant":
            if mnv_con == "synonymous_variant":
                return ("Unchanged")
            elif mnv_con == "missense_variant":
                return ("Gained missense")
            elif mnv_con == "stop_gained":
                return ("Gained PTV")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "missense_variant":
            if mnv_con == "synonymous_variant":
                return ("Lost missense")
            elif mnv_con == "missense_variant":
                return (mnv_category_by_aa_change(snp1_con, snp2_con, mnv_con, aa1, aa2, aa3))  # go look at aa change.
            elif mnv_con == "stop_gained":
                return ("Gained PTV")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "stop_gained":
            if mnv_con == "synonymous_variant":
                return ("Rescued PTV")
            elif mnv_con == "missense_variant":
                return ("Rescued PTV")
            elif mnv_con == "stop_gained":
                return ("Unchanged")
            else:
                return ("Noncoding_or_else")
    if snp1_con == "missense_variant":
        if snp2_con == "synonymous_variant":
            if mnv_con == "synonymous_variant":
                return ("Lost missense")
            elif mnv_con == "missense_variant":
                return (mnv_category_by_aa_change(snp1_con, snp2_con, mnv_con, aa1, aa2, aa3))  # go look at aa change.
            elif mnv_con == "stop_gained":
                return ("Gained PTV")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "missense_variant":
            if mnv_con == "synonymous_variant":
                return ("Lost missense")
            elif mnv_con == "missense_variant":
                return (mnv_category_by_aa_change(snp1_con, snp2_con, mnv_con, aa1, aa2, aa3))  # go look at aa change.
            elif mnv_con == "stop_gained":
                return ("Gained PTV")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "stop_gained":
            if mnv_con == "synonymous_variant":
                return ("Rescued PTV")
            elif mnv_con == "missense_variant":
                return ("Rescued PTV")
            elif mnv_con == "stop_gained":
                return ("Unchanged")
            else:
                return ("Noncoding_or_else")
        else:
            return ("Noncoding_or_else")
    if snp1_con == "stop_gained":
        if snp2_con == "synonymous_variant":
            if mnv_con == "synonymous_variant":
                return ("Rescued PTV")
            elif mnv_con == "missense_variant":
                return ("Rescued PTV")
            elif mnv_con == "stop_gained":
                return ("Unchanged")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "missense_variant":
            if mnv_con == "synonymous_variant":
                return ("Rescued PTV")
            elif mnv_con == "missense_variant":
                return ("Rescued PTV")
            elif mnv_con == "stop_gained":
                return ("Unchanged")
            else:
                return ("Noncoding_or_else")
        if snp2_con == "stop_gained":
            if mnv_con == "synonymous_variant":
                return ("Rescued PTV")
            elif mnv_con == "missense_variant":
                return ("Rescued PTV")
            elif mnv_con == "stop_gained":
                return ("Unchanged")
            else:
                return ("Noncoding_or_else")
        else:
            return ("Noncoding_or_else")
    #else, involving start_loss etc -> look at mnv cons first.
    elif mnv_con=="start_lost": return "Unchanged" #by definition individual effect is also start loss
    elif mnv_con=="stop_lost":
        if ((snp1_con=="stop_retained_variant") & (snp2_con=="stop_retained_variant")): return "gained_stop_loss"
        else: return ("Unchanged")
    elif mnv_con=="stop_retained_variant":#this case, by definition one of the variant is stop_lost, and the other is stop_retained
        return ("Rescued stop loss")
    else:
        return ("Noncoding_or_else")
